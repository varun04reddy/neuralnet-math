# %%
import pandas as pd
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
import math, torch
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from captum.attr import IntegratedGradients

# %%
df = pd.read_csv('arithmetic_data.csv')

# %%
class MathLSTMModel(nn.Module):
    def __init__(self, vocab_size, embed_dim=16, hidden_dim=32):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.embedding(x)               # [batch, seq_len, embed_dim]
        lstm_out, (h_n, c_n) = self.lstm(x)
        final_hidden = h_n[-1]
        out = self.fc(final_hidden)
        return out.squeeze(1)

# %%
df.rename(columns={"=": "eq"}, inplace=True)
rows = list(df.itertuples(index=False, name=None))

# Build vocab
vocab = sorted(set(str(x) for row in rows for x in row[:-1]))
token2idx = {tok: i for i, tok in enumerate(vocab)}

# Encode
def encode(row):
    x, op, y, eq, res = row
    tokens = [str(x), op, str(y), eq]
    indices = [token2idx[tok] for tok in tokens]
    return indices, float(res)

encoded = [encode(row) for row in rows]
inputs = torch.tensor([e[0] for e in encoded], dtype=torch.long)
targets = torch.tensor([e[1] for e in encoded], dtype=torch.float32)

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, targets, test_size=0.2, random_state=42)

# %%
model = MathLSTMModel(vocab_size=len(token2idx))
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

from tqdm import trange

num_epochs = 500
loop = trange(num_epochs)

for epoch in loop:
    model.train()
    preds = model(X_train)
    loss = loss_fn(preds, y_train)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    loop.set_description(f"Epoch {epoch}")
    loop.set_postfix(train_loss=loss.item())

    if epoch % 50 == 0 or epoch == num_epochs - 1:
        model.eval()
        with torch.no_grad():
            val_preds = model(X_test)
            val_loss = loss_fn(val_preds, y_test)
        print(f"Epoch {epoch} | Train Loss: {loss.item():.4f}, Test Loss: {val_loss.item():.4f}")
# Out:
# Epoch 0:   0%|          | 1/500 [00:00<02:51,  2.91it/s, train_loss=2.81e+6]
# Epoch 0 | Train Loss: 2808776.0000, Test Loss: 2900405.7500
# Epoch 50:  10%|█         | 51/500 [00:15<06:55,  1.08it/s, train_loss=2.78e+6]
# Epoch 50 | Train Loss: 2783902.0000, Test Loss: 2874981.7500
# Epoch 100:  20%|██        | 101/500 [00:36<02:19,  2.86it/s, train_loss=2.76e+6]
# Epoch 100 | Train Loss: 2761272.5000, Test Loss: 2852092.7500
# Epoch 150:  30%|███       | 151/500 [00:58<01:58,  2.96it/s, train_loss=2.74e+6]
# Epoch 150 | Train Loss: 2738963.0000, Test Loss: 2829518.7500
# Epoch 201:  40%|████      | 202/500 [01:14<01:00,  4.91it/s, train_loss=2.72e+6]
# Epoch 200 | Train Loss: 2717640.2500, Test Loss: 2807935.2500
# Epoch 250:  50%|█████     | 251/500 [01:23<00:54,  4.59it/s, train_loss=2.7e+6]
# Epoch 250 | Train Loss: 2696974.0000, Test Loss: 2787006.7500
# Epoch 300:  60%|██████    | 301/500 [01:43<01:09,  2.87it/s, train_loss=2.68e+6]
# Epoch 300 | Train Loss: 2676814.2500, Test Loss: 2766587.5000
# Epoch 350:  70%|███████   | 351/500 [02:01<00:39,  3.82it/s, train_loss=2.66e+6]
# Epoch 350 | Train Loss: 2657062.7500, Test Loss: 2746576.0000
# Epoch 401:  80%|████████  | 402/500 [02:11<00:20,  4.88it/s, train_loss=2.64e+6]
# Epoch 400 | Train Loss: 2637617.5000, Test Loss: 2726870.7500
# Epoch 450:  90%|█████████ | 451/500 [02:40<00:27,  1.80it/s, train_loss=2.62e+6]
# Epoch 450 | Train Loss: 2618430.2500, Test Loss: 2707421.5000
# Epoch 499: 100%|██████████| 500/500 [03:02<00:00,  2.73it/s, train_loss=2.6e+6]
# Epoch 499 | Train Loss: 2599845.5000, Test Loss: 2688576.7500

# %%
model.eval()
with torch.no_grad():
    preds = model(X_test)
    for i in range(len(X_test)):
        tok_ids = X_test[i]
        equation = " ".join([list(token2idx.keys())[idx] for idx in tok_ids])
        print(f"{equation} → Predicted: {preds[i].item():.2f}, Actual: {y_test[i].item()}")
# Out:
# 85 * 96 = → Predicted: 168.56, Actual: 8160.0
# 52 / 1 = → Predicted: 51.39, Actual: 52.0
# 56 * 73 = → Predicted: 168.56, Actual: 4088.0
# 56 * 11 = → Predicted: 168.55, Actual: 616.0
# 81 / 3 = → Predicted: 27.15, Actual: 27.0
# 37 - 57 = → Predicted: -20.89, Actual: -20.0
# 90 + 61 = → Predicted: 151.68, Actual: 151.0
# 58 - 87 = → Predicted: -29.61, Actual: -29.0
# 52 / 52 = → Predicted: 0.40, Actual: 1.0
# 86 + 38 = → Predicted: 124.76, Actual: 124.0
# 66 / 22 = → Predicted: 3.75, Actual: 3.0
# 84 / 21 = → Predicted: 4.27, Actual: 4.0
# 58 + 68 = → Predicted: 125.13, Actual: 126.0
# 18 + 21 = → Predicted: 39.14, Actual: 39.0
# 20 + 59 = → Predicted: 77.94, Actual: 79.0
# 3 - 23 = → Predicted: -20.86, Actual: -20.0
# 92 + 58 = → Predicted: 151.86, Actual: 150.0
# 53 + 92 = → Predicted: 145.33, Actual: 145.0
# 13 + 48 = → Predicted: 61.99, Actual: 61.0
# 70 * 71 = → Predicted: 168.56, Actual: 4970.0
# 36 * 1 = → Predicted: 163.53, Actual: 36.0
# 99 / 1 = → Predicted: 97.21, Actual: 99.0
# 7 / 1 = → Predicted: 7.75, Actual: 7.0
# 3 - 47 = → Predicted: -44.97, Actual: -44.0
# 87 / 87 = → Predicted: 1.19, Actual: 1.0
# 52 * 14 = → Predicted: 168.55, Actual: 728.0
# 50 + 3 = → Predicted: 52.64, Actual: 53.0
# 89 - 31 = → Predicted: 58.08, Actual: 58.0
# 18 - 98 = → Predicted: -80.36, Actual: -80.0
# 49 + 99 = → Predicted: 145.64, Actual: 148.0
# 63 + 69 = → Predicted: 130.47, Actual: 132.0
# 99 + 95 = → Predicted: 167.46, Actual: 194.0
# 62 / 31 = → Predicted: 3.16, Actual: 2.0
# 47 / 1 = → Predicted: 46.70, Actual: 47.0
# 32 - 72 = → Predicted: -38.84, Actual: -40.0
# 89 * 51 = → Predicted: 168.56, Actual: 4539.0
# 8 - 87 = → Predicted: -78.90, Actual: -79.0
# 38 / 1 = → Predicted: 37.64, Actual: 38.0
# 59 / 59 = → Predicted: -0.01, Actual: 1.0
# 70 + 84 = → Predicted: 155.09, Actual: 154.0
# 1 + 69 = → Predicted: 69.26, Actual: 70.0
# 85 / 85 = → Predicted: 1.17, Actual: 1.0
# 68 + 79 = → Predicted: 145.98, Actual: 147.0
# 68 + 47 = → Predicted: 114.19, Actual: 115.0
# 34 * 23 = → Predicted: 168.55, Actual: 782.0
# 10 - 72 = → Predicted: -59.44, Actual: -62.0
# 52 - 66 = → Predicted: -14.70, Actual: -14.0
# 19 / 1 = → Predicted: 19.34, Actual: 19.0
# 1 + 16 = → Predicted: 14.85, Actual: 17.0
# 36 * 19 = → Predicted: 168.55, Actual: 684.0
# 47 - 46 = → Predicted: -0.05, Actual: 1.0
# 63 - 29 = → Predicted: 32.36, Actual: 34.0
# 84 - 40 = → Predicted: 43.65, Actual: 44.0
# 13 - 49 = → Predicted: -35.19, Actual: -36.0
# 38 * 47 = → Predicted: 168.55, Actual: 1786.0
# 9 / 1 = → Predicted: 8.66, Actual: 9.0
# 68 / 68 = → Predicted: 0.71, Actual: 1.0
# 16 - 99 = → Predicted: -85.51, Actual: -83.0
# 81 + 63 = → Predicted: 144.81, Actual: 144.0
# 94 * 54 = → Predicted: 168.56, Actual: 5076.0
# 84 / 4 = → Predicted: 19.17, Actual: 21.0
# 96 / 6 = → Predicted: 11.42, Actual: 16.0
# 40 * 95 = → Predicted: 168.55, Actual: 3800.0
# 81 / 27 = → Predicted: 4.09, Actual: 3.0
# 64 - 68 = → Predicted: -3.53, Actual: -4.0
# 73 * 22 = → Predicted: 168.55, Actual: 1606.0
# 96 / 6 = → Predicted: 11.42, Actual: 16.0
# 45 + 67 = → Predicted: 112.26, Actual: 112.0
# 44 + 95 = → Predicted: 137.19, Actual: 139.0
# 49 / 1 = → Predicted: 47.75, Actual: 49.0
# 27 / 27 = → Predicted: -0.70, Actual: 1.0
# 47 / 47 = → Predicted: 1.74, Actual: 1.0
# 96 / 96 = → Predicted: 1.22, Actual: 1.0
# 48 * 59 = → Predicted: 168.55, Actual: 2832.0
# 37 + 55 = → Predicted: 91.11, Actual: 92.0
# 69 - 8 = → Predicted: 61.15, Actual: 61.0
# 76 * 22 = → Predicted: 168.55, Actual: 1672.0
# 70 - 96 = → Predicted: -26.30, Actual: -26.0
# 9 / 9 = → Predicted: 0.05, Actual: 1.0
# 13 + 7 = → Predicted: 17.24, Actual: 20.0
# 77 / 7 = → Predicted: 12.37, Actual: 11.0
# 7 / 1 = → Predicted: 7.75, Actual: 7.0
# 69 * 62 = → Predicted: 168.56, Actual: 4278.0
# 1 * 89 = → Predicted: 168.27, Actual: 89.0
# 15 - 54 = → Predicted: -40.53, Actual: -39.0
# 82 - 31 = → Predicted: 50.73, Actual: 51.0
# 45 / 3 = → Predicted: 14.93, Actual: 15.0
# 2 * 82 = → Predicted: 168.31, Actual: 164.0
# 70 * 36 = → Predicted: 168.56, Actual: 2520.0
# 87 / 3 = → Predicted: 28.33, Actual: 29.0
# 30 / 5 = → Predicted: 6.46, Actual: 6.0
# 21 + 69 = → Predicted: 89.80, Actual: 90.0
# 4 * 33 = → Predicted: 168.49, Actual: 132.0
# 54 - 65 = → Predicted: -10.97, Actual: -11.0
# 92 / 2 = → Predicted: 45.75, Actual: 46.0
# 31 / 1 = → Predicted: 31.03, Actual: 31.0
# 12 * 31 = → Predicted: 168.52, Actual: 372.0
# 85 * 31 = → Predicted: 168.56, Actual: 2635.0
# 18 * 17 = → Predicted: 168.53, Actual: 306.0
# 92 - 56 = → Predicted: 34.85, Actual: 36.0
# 82 + 23 = → Predicted: 105.25, Actual: 105.0
# 63 + 16 = → Predicted: 79.13, Actual: 79.0
# 65 * 5 = → Predicted: 168.50, Actual: 325.0
# 7 - 10 = → Predicted: -0.59, Actual: -3.0
# 26 / 2 = → Predicted: 13.11, Actual: 13.0
# 18 - 98 = → Predicted: -80.36, Actual: -80.0
# 6 * 3 = → Predicted: 168.48, Actual: 18.0
# 86 + 51 = → Predicted: 135.33, Actual: 137.0
# 6 - 47 = → Predicted: -42.02, Actual: -41.0
# 73 + 4 = → Predicted: 76.81, Actual: 77.0
# 13 - 79 = → Predicted: -64.30, Actual: -66.0
# 73 + 16 = → Predicted: 87.81, Actual: 89.0
# 72 - 30 = → Predicted: 42.11, Actual: 42.0
# 47 / 1 = → Predicted: 46.70, Actual: 47.0
# 62 - 33 = → Predicted: 28.10, Actual: 29.0
# 52 * 65 = → Predicted: 168.56, Actual: 3380.0
# 5 * 87 = → Predicted: 168.48, Actual: 435.0
# 47 / 1 = → Predicted: 46.70, Actual: 47.0
# 76 * 96 = → Predicted: 168.56, Actual: 7296.0
# 31 - 24 = → Predicted: 6.17, Actual: 7.0
# 46 / 46 = → Predicted: 1.02, Actual: 1.0
# 31 * 25 = → Predicted: 168.55, Actual: 775.0
# 96 - 82 = → Predicted: 11.22, Actual: 14.0
# 85 * 22 = → Predicted: 168.56, Actual: 1870.0
# 49 + 95 = → Predicted: 141.72, Actual: 144.0
# 94 * 95 = → Predicted: 168.56, Actual: 8930.0
# 42 * 32 = → Predicted: 168.55, Actual: 1344.0
# 32 - 98 = → Predicted: -66.48, Actual: -66.0
# 62 / 2 = → Predicted: 30.91, Actual: 31.0
# 99 / 3 = → Predicted: 30.20, Actual: 33.0
# 48 / 12 = → Predicted: 4.42, Actual: 4.0
# 63 + 67 = → Predicted: 128.62, Actual: 130.0
# 24 - 22 = → Predicted: 2.73, Actual: 2.0
# 46 * 81 = → Predicted: 168.55, Actual: 3726.0
# 94 - 89 = → Predicted: 2.87, Actual: 5.0
# 75 * 58 = → Predicted: 168.56, Actual: 4350.0
# 91 * 40 = → Predicted: 168.56, Actual: 3640.0
# 82 + 90 = → Predicted: 166.00, Actual: 172.0
# 46 - 72 = → Predicted: -25.38, Actual: -26.0
# 24 / 2 = → Predicted: 11.95, Actual: 12.0
# 20 + 82 = → Predicted: 101.67, Actual: 102.0
# 74 + 8 = → Predicted: 81.14, Actual: 82.0
# 14 + 42 = → Predicted: 54.37, Actual: 56.0
# 39 - 37 = → Predicted: 0.57, Actual: 2.0
# 57 / 19 = → Predicted: 3.98, Actual: 3.0
# 24 - 85 = → Predicted: -60.80, Actual: -61.0
# 39 + 40 = → Predicted: 76.88, Actual: 79.0
# 91 - 58 = → Predicted: 32.66, Actual: 33.0
# 56 / 1 = → Predicted: 55.56, Actual: 56.0
# 99 * 93 = → Predicted: 168.56, Actual: 9207.0
# 40 + 29 = → Predicted: 68.38, Actual: 69.0
# 58 - 86 = → Predicted: -28.75, Actual: -28.0
# 39 + 45 = → Predicted: 82.35, Actual: 84.0
# 83 * 69 = → Predicted: 168.56, Actual: 5727.0
# 100 - 54 = → Predicted: 45.72, Actual: 46.0
# 69 + 84 = → Predicted: 153.48, Actual: 153.0
# 1 * 74 = → Predicted: 168.27, Actual: 74.0
# 34 + 56 = → Predicted: 88.89, Actual: 90.0
# 63 - 77 = → Predicted: -15.54, Actual: -14.0
# 46 - 55 = → Predicted: -9.54, Actual: -9.0
# 96 / 3 = → Predicted: 30.11, Actual: 32.0
# 46 * 88 = → Predicted: 168.55, Actual: 4048.0
# 93 * 3 = → Predicted: 168.54, Actual: 279.0
# 70 / 1 = → Predicted: 69.02, Actual: 70.0
# 55 + 20 = → Predicted: 75.53, Actual: 75.0
# 19 * 51 = → Predicted: 168.54, Actual: 969.0
# 93 * 40 = → Predicted: 168.56, Actual: 3720.0
# 81 / 27 = → Predicted: 4.09, Actual: 3.0
# 45 - 75 = → Predicted: -29.10, Actual: -30.0
# 100 + 89 = → Predicted: 167.38, Actual: 189.0
# 23 / 23 = → Predicted: 0.25, Actual: 1.0
# 27 / 9 = → Predicted: 2.72, Actual: 3.0
# 27 + 29 = → Predicted: 55.50, Actual: 56.0
# 2 - 2 = → Predicted: 2.48, Actual: 0.0
# 39 + 87 = → Predicted: 125.00, Actual: 126.0
# 41 / 41 = → Predicted: 0.82, Actual: 1.0
# 52 - 34 = → Predicted: 17.03, Actual: 18.0
# 55 / 11 = → Predicted: 5.19, Actual: 5.0
# 69 + 57 = → Predicted: 124.56, Actual: 126.0
# 67 + 81 = → Predicted: 148.23, Actual: 148.0
# 67 * 32 = → Predicted: 168.56, Actual: 2144.0
# 52 * 46 = → Predicted: 168.56, Actual: 2392.0
# 26 - 29 = → Predicted: -3.03, Actual: -3.0
# 28 * 47 = → Predicted: 168.55, Actual: 1316.0
# 3 * 26 = → Predicted: 168.47, Actual: 78.0
# 94 + 87 = → Predicted: 167.00, Actual: 181.0
# 61 - 20 = → Predicted: 39.61, Actual: 41.0
# 38 + 55 = → Predicted: 91.41, Actual: 93.0
# 84 * 70 = → Predicted: 168.56, Actual: 5880.0
# 70 + 40 = → Predicted: 111.49, Actual: 110.0
# 51 / 3 = → Predicted: 16.95, Actual: 17.0
# 17 / 17 = → Predicted: 0.44, Actual: 1.0
# 84 * 48 = → Predicted: 168.56, Actual: 4032.0
# 48 + 78 = → Predicted: 125.65, Actual: 126.0
# 56 * 51 = → Predicted: 168.56, Actual: 2856.0
# 34 - 90 = → Predicted: -55.46, Actual: -56.0
# 67 / 67 = → Predicted: 1.17, Actual: 1.0
# 73 - 71 = → Predicted: 2.40, Actual: 2.0
# 92 * 26 = → Predicted: 168.56, Actual: 2392.0
# 99 * 65 = → Predicted: 168.56, Actual: 6435.0
# 45 / 45 = → Predicted: 1.25, Actual: 1.0
# 41 * 52 = → Predicted: 168.55, Actual: 2132.0
# 72 * 89 = → Predicted: 168.56, Actual: 6408.0
# 78 / 39 = → Predicted: 2.02, Actual: 2.0
# 37 + 80 = → Predicted: 117.75, Actual: 117.0
# 96 / 2 = → Predicted: 47.22, Actual: 48.0
# 45 + 95 = → Predicted: 139.43, Actual: 140.0
# 21 / 21 = → Predicted: -0.32, Actual: 1.0
# 74 - 12 = → Predicted: 61.61, Actual: 62.0
# 54 * 60 = → Predicted: 168.56, Actual: 3240.0
# 18 - 70 = → Predicted: -54.20, Actual: -52.0
# 89 - 75 = → Predicted: 13.79, Actual: 14.0
# 61 * 4 = → Predicted: 168.54, Actual: 244.0
# 48 / 6 = → Predicted: 8.00, Actual: 8.0
# 18 * 67 = → Predicted: 168.53, Actual: 1206.0
# 51 * 58 = → Predicted: 168.55, Actual: 2958.0
# 78 / 6 = → Predicted: 10.88, Actual: 13.0
# 90 + 70 = → Predicted: 162.00, Actual: 160.0
# 57 + 32 = → Predicted: 87.41, Actual: 89.0
# 10 / 1 = → Predicted: 8.79, Actual: 10.0
# 41 - 26 = → Predicted: 14.95, Actual: 15.0
# 44 * 4 = → Predicted: 168.54, Actual: 176.0
# 25 * 80 = → Predicted: 168.55, Actual: 2000.0
# 41 / 1 = → Predicted: 40.76, Actual: 41.0
# 76 - 22 = → Predicted: 52.08, Actual: 54.0
# 3 * 73 = → Predicted: 168.48, Actual: 219.0
# 13 + 7 = → Predicted: 17.24, Actual: 20.0
# 73 / 73 = → Predicted: 0.72, Actual: 1.0
# 43 * 43 = → Predicted: 168.55, Actual: 1849.0
# 49 * 9 = → Predicted: 168.55, Actual: 441.0
# 74 + 41 = → Predicted: 115.28, Actual: 115.0
# 63 + 63 = → Predicted: 125.00, Actual: 126.0
# 73 + 63 = → Predicted: 135.27, Actual: 136.0
# 17 * 93 = → Predicted: 168.53, Actual: 1581.0
# 29 + 71 = → Predicted: 100.68, Actual: 100.0
# 20 + 58 = → Predicted: 75.96, Actual: 78.0
# 21 + 2 = → Predicted: 21.71, Actual: 23.0
# 20 - 43 = → Predicted: -25.24, Actual: -23.0
# 6 * 19 = → Predicted: 168.50, Actual: 114.0
# 39 + 10 = → Predicted: 49.49, Actual: 49.0
# 45 / 9 = → Predicted: 5.67, Actual: 5.0
# 95 * 2 = → Predicted: 163.65, Actual: 190.0
# 88 / 22 = → Predicted: 4.58, Actual: 4.0
# 11 / 11 = → Predicted: -0.38, Actual: 1.0
# 54 - 26 = → Predicted: 26.79, Actual: 28.0
# 47 + 23 = → Predicted: 68.91, Actual: 70.0
# 27 / 1 = → Predicted: 26.82, Actual: 27.0
# 50 + 81 = → Predicted: 129.22, Actual: 131.0
# 43 * 68 = → Predicted: 168.55, Actual: 2924.0
# 69 * 26 = → Predicted: 168.56, Actual: 1794.0
# 62 * 68 = → Predicted: 168.56, Actual: 4216.0
# 48 / 12 = → Predicted: 4.42, Actual: 4.0
# 93 / 1 = → Predicted: 91.74, Actual: 93.0
# 11 * 21 = → Predicted: 168.53, Actual: 231.0
# 35 - 30 = → Predicted: 5.26, Actual: 5.0
# 38 / 2 = → Predicted: 18.68, Actual: 19.0
# 14 - 37 = → Predicted: -24.83, Actual: -23.0
# 85 - 98 = → Predicted: -14.70, Actual: -13.0
# 91 - 39 = → Predicted: 51.04, Actual: 52.0
# 48 + 96 = → Predicted: 143.62, Actual: 144.0
# 50 / 2 = → Predicted: 24.68, Actual: 25.0
# 29 / 29 = → Predicted: 0.13, Actual: 1.0
# 65 / 5 = → Predicted: 12.96, Actual: 13.0
# 47 + 17 = → Predicted: 63.84, Actual: 64.0
# 18 + 22 = → Predicted: 41.06, Actual: 40.0
# 32 - 56 = → Predicted: -24.89, Actual: -24.0
# 34 * 98 = → Predicted: 168.55, Actual: 3332.0
# 48 + 89 = → Predicted: 135.81, Actual: 137.0
# 78 - 10 = → Predicted: 69.80, Actual: 68.0
# 66 * 72 = → Predicted: 168.56, Actual: 4752.0
# 37 - 44 = → Predicted: -6.98, Actual: -7.0
# 5 * 11 = → Predicted: 168.44, Actual: 55.0
# 4 / 1 = → Predicted: 4.21, Actual: 4.0
# 85 - 70 = → Predicted: 16.07, Actual: 15.0
# 36 - 46 = → Predicted: -10.51, Actual: -10.0
# 16 * 15 = → Predicted: 168.51, Actual: 240.0
# 100 * 40 = → Predicted: 168.56, Actual: 4000.0
# 47 + 78 = → Predicted: 125.09, Actual: 125.0
# 51 - 86 = → Predicted: -35.67, Actual: -35.0
# 51 / 17 = → Predicted: 4.12, Actual: 3.0
# 7 + 67 = → Predicted: 69.74, Actual: 74.0
# 8 - 60 = → Predicted: -52.57, Actual: -52.0
# 16 + 49 = → Predicted: 63.81, Actual: 65.0
# 93 / 31 = → Predicted: 4.19, Actual: 3.0
# 72 + 45 = → Predicted: 116.08, Actual: 117.0
# 54 + 9 = → Predicted: 62.54, Actual: 63.0
# 12 + 57 = → Predicted: 66.53, Actual: 69.0
# 84 - 47 = → Predicted: 35.43, Actual: 37.0
# 84 * 37 = → Predicted: 168.56, Actual: 3108.0
# 91 - 92 = → Predicted: -2.94, Actual: -1.0
# 77 * 40 = → Predicted: 168.56, Actual: 3080.0
# 81 + 91 = → Predicted: 165.99, Actual: 172.0
# 87 - 47 = → Predicted: 38.66, Actual: 40.0
# 4 - 21 = → Predicted: -16.30, Actual: -17.0
# 70 / 1 = → Predicted: 69.02, Actual: 70.0
# 65 * 22 = → Predicted: 168.55, Actual: 1430.0
# 46 + 78 = → Predicted: 124.47, Actual: 124.0
# 89 * 66 = → Predicted: 168.56, Actual: 5874.0
# 94 - 33 = → Predicted: 58.71, Actual: 61.0
# 98 / 49 = → Predicted: 1.17, Actual: 2.0
# 10 + 22 = → Predicted: 34.18, Actual: 32.0
# 26 - 33 = → Predicted: -7.91, Actual: -7.0
# 98 - 57 = → Predicted: 40.63, Actual: 41.0
# 89 / 1 = → Predicted: 86.91, Actual: 89.0
# 35 / 5 = → Predicted: 7.84, Actual: 7.0
# 1 - 35 = → Predicted: -40.47, Actual: -34.0
# 76 - 78 = → Predicted: -2.09, Actual: -2.0
# 53 / 53 = → Predicted: 0.78, Actual: 1.0
# 18 * 84 = → Predicted: 168.53, Actual: 1512.0
# 39 / 1 = → Predicted: 37.62, Actual: 39.0
# 87 / 1 = → Predicted: 86.81, Actual: 87.0
# 53 / 53 = → Predicted: 0.78, Actual: 1.0
# 39 - 7 = → Predicted: 31.09, Actual: 32.0
# 3 / 3 = → Predicted: 1.08, Actual: 1.0
# 79 / 79 = → Predicted: 1.13, Actual: 1.0
# 78 + 54 = → Predicted: 131.21, Actual: 132.0
# 20 - 76 = → Predicted: -56.38, Actual: -56.0
# 85 * 86 = → Predicted: 168.56, Actual: 7310.0
# 46 * 72 = → Predicted: 168.55, Actual: 3312.0
# 28 * 13 = → Predicted: 168.54, Actual: 364.0
# 73 - 43 = → Predicted: 29.65, Actual: 30.0
# 35 - 99 = → Predicted: -65.88, Actual: -64.0
# 16 - 12 = → Predicted: 3.58, Actual: 4.0
# 83 * 47 = → Predicted: 168.56, Actual: 3901.0
# 18 / 3 = → Predicted: 5.86, Actual: 6.0
# 55 + 50 = → Predicted: 106.39, Actual: 105.0
# 50 - 100 = → Predicted: -51.28, Actual: -50.0
# 35 - 96 = → Predicted: -61.36, Actual: -61.0
# 46 / 23 = → Predicted: 2.72, Actual: 2.0
# 12 - 27 = → Predicted: -15.03, Actual: -15.0
# 14 + 32 = → Predicted: 46.87, Actual: 46.0
# 98 + 84 = → Predicted: 167.13, Actual: 182.0
# 52 + 12 = → Predicted: 64.38, Actual: 64.0
# 17 + 57 = → Predicted: 71.90, Actual: 74.0
# 22 / 22 = → Predicted: -0.77, Actual: 1.0
# 49 - 52 = → Predicted: -3.20, Actual: -3.0
# 80 + 75 = → Predicted: 155.72, Actual: 155.0
# 40 * 33 = → Predicted: 168.55, Actual: 1320.0
# 23 * 62 = → Predicted: 168.55, Actual: 1426.0
# 84 / 42 = → Predicted: 1.90, Actual: 2.0
# 37 + 19 = → Predicted: 55.12, Actual: 56.0
# 47 + 41 = → Predicted: 85.98, Actual: 88.0
# 35 * 66 = → Predicted: 168.55, Actual: 2310.0
# 54 + 37 = → Predicted: 89.01, Actual: 91.0
# 1 + 32 = → Predicted: 34.81, Actual: 33.0
# 41 * 49 = → Predicted: 168.55, Actual: 2009.0
# 64 + 99 = → Predicted: 161.35, Actual: 163.0
# 4 + 73 = → Predicted: 74.87, Actual: 77.0
# 98 + 64 = → Predicted: 163.52, Actual: 162.0
# 77 / 7 = → Predicted: 12.37, Actual: 11.0
# 69 + 91 = → Predicted: 160.75, Actual: 160.0
# 68 + 86 = → Predicted: 155.38, Actual: 154.0
# 99 - 88 = → Predicted: 7.33, Actual: 11.0
# 43 + 26 = → Predicted: 68.64, Actual: 69.0
# 72 - 47 = → Predicted: 23.62, Actual: 25.0
# 61 / 1 = → Predicted: 60.11, Actual: 61.0
# 4 - 64 = → Predicted: -60.78, Actual: -60.0
# 41 + 32 = → Predicted: 72.19, Actual: 73.0
# 9 - 35 = → Predicted: -26.92, Actual: -26.0
# 95 - 88 = → Predicted: 5.57, Actual: 7.0
# 54 - 96 = → Predicted: -42.47, Actual: -42.0
# 21 / 1 = → Predicted: 21.13, Actual: 21.0
# 7 + 19 = → Predicted: 27.48, Actual: 26.0
# 40 - 44 = → Predicted: -4.58, Actual: -4.0
# 11 + 60 = → Predicted: 69.95, Actual: 71.0
# 19 - 65 = → Predicted: -46.08, Actual: -46.0
# 5 / 5 = → Predicted: -0.69, Actual: 1.0
# 21 + 42 = → Predicted: 62.26, Actual: 63.0
# 48 - 1 = → Predicted: 47.30, Actual: 47.0
# 30 / 30 = → Predicted: 2.28, Actual: 1.0
# 65 + 17 = → Predicted: 80.64, Actual: 82.0
# 80 + 71 = → Predicted: 151.41, Actual: 151.0
# 25 / 1 = → Predicted: 24.69, Actual: 25.0
# 76 * 15 = → Predicted: 168.55, Actual: 1140.0
# 98 + 54 = → Predicted: 152.97, Actual: 152.0
# 29 + 30 = → Predicted: 60.49, Actual: 59.0
# 12 + 27 = → Predicted: 37.46, Actual: 39.0
# 77 / 11 = → Predicted: 7.04, Actual: 7.0
# 64 - 8 = → Predicted: 56.14, Actual: 56.0
# 44 / 44 = → Predicted: 1.70, Actual: 1.0
# 45 / 1 = → Predicted: 43.89, Actual: 45.0
# 45 / 5 = → Predicted: 9.49, Actual: 9.0
# 10 * 87 = → Predicted: 168.50, Actual: 870.0
# 38 * 75 = → Predicted: 168.55, Actual: 2850.0
# 35 - 20 = → Predicted: 13.58, Actual: 15.0
# 19 + 17 = → Predicted: 35.40, Actual: 36.0
# 17 * 22 = → Predicted: 168.53, Actual: 374.0
# 36 / 3 = → Predicted: 11.69, Actual: 12.0
# 43 * 74 = → Predicted: 168.55, Actual: 3182.0
# 48 - 69 = → Predicted: -21.93, Actual: -21.0
# 80 - 24 = → Predicted: 53.82, Actual: 56.0
# 9 * 47 = → Predicted: 168.50, Actual: 423.0
# 26 / 13 = → Predicted: 2.90, Actual: 2.0
# 96 * 61 = → Predicted: 168.56, Actual: 5856.0
# 69 * 83 = → Predicted: 168.56, Actual: 5727.0
# 22 * 48 = → Predicted: 168.54, Actual: 1056.0
# 86 / 43 = → Predicted: 1.74, Actual: 2.0
# 9 / 9 = → Predicted: 0.05, Actual: 1.0
# 98 + 47 = → Predicted: 146.01, Actual: 145.0
# 98 + 14 = → Predicted: 110.01, Actual: 112.0
# 41 + 39 = → Predicted: 79.42, Actual: 80.0
# 46 - 57 = → Predicted: -11.90, Actual: -11.0
# 85 - 76 = → Predicted: 9.57, Actual: 9.0
# 54 * 52 = → Predicted: 168.56, Actual: 2808.0
# 46 * 54 = → Predicted: 168.55, Actual: 2484.0
# 68 * 1 = → Predicted: 163.53, Actual: 68.0
# 99 / 9 = → Predicted: 7.80, Actual: 11.0
# 12 / 3 = → Predicted: 4.24, Actual: 4.0
# 2 - 3 = → Predicted: 1.10, Actual: -1.0
# 27 + 58 = → Predicted: 83.48, Actual: 85.0
# 18 * 31 = → Predicted: 168.53, Actual: 558.0
# 10 / 5 = → Predicted: 2.06, Actual: 2.0
# 59 * 76 = → Predicted: 168.56, Actual: 4484.0
# 80 * 7 = → Predicted: 168.54, Actual: 560.0
# 84 / 21 = → Predicted: 4.27, Actual: 4.0
# 30 + 41 = → Predicted: 69.19, Actual: 71.0
# 1 * 88 = → Predicted: 168.27, Actual: 88.0
# 66 + 7 = → Predicted: 68.54, Actual: 73.0
# 46 + 91 = → Predicted: 137.24, Actual: 137.0
# 16 / 4 = → Predicted: 6.33, Actual: 4.0
# 11 + 39 = → Predicted: 46.61, Actual: 50.0
# 14 + 8 = → Predicted: 23.52, Actual: 22.0
# 34 * 10 = → Predicted: 168.54, Actual: 340.0
# 2 / 1 = → Predicted: 2.35, Actual: 2.0
# 87 * 10 = → Predicted: 168.55, Actual: 870.0
# 99 + 13 = → Predicted: 110.11, Actual: 112.0
# 43 - 25 = → Predicted: 18.14, Actual: 18.0
# 99 * 40 = → Predicted: 168.56, Actual: 3960.0
# 34 * 38 = → Predicted: 168.55, Actual: 1292.0
# 5 / 5 = → Predicted: -0.69, Actual: 1.0
# 35 - 38 = → Predicted: -3.33, Actual: -3.0
# 86 + 76 = → Predicted: 163.17, Actual: 162.0
# 15 + 67 = → Predicted: 79.17, Actual: 82.0
# 53 * 2 = → Predicted: 163.65, Actual: 106.0
# 25 * 62 = → Predicted: 168.55, Actual: 1550.0
# 54 - 32 = → Predicted: 20.77, Actual: 22.0
# 83 + 74 = → Predicted: 159.10, Actual: 157.0
# 38 * 49 = → Predicted: 168.55, Actual: 1862.0
# 3 - 16 = → Predicted: -11.53, Actual: -13.0
# 59 / 59 = → Predicted: -0.01, Actual: 1.0
# 59 + 23 = → Predicted: 83.53, Actual: 82.0
# 60 * 96 = → Predicted: 168.56, Actual: 5760.0
# 22 / 11 = → Predicted: 2.32, Actual: 2.0
# 60 * 41 = → Predicted: 168.55, Actual: 2460.0
# 89 - 54 = → Predicted: 35.83, Actual: 35.0
# 40 + 86 = → Predicted: 124.61, Actual: 126.0
# 28 + 100 = → Predicted: 128.40, Actual: 128.0
# 22 + 60 = → Predicted: 82.23, Actual: 82.0
# 39 / 39 = → Predicted: 1.31, Actual: 1.0
# 87 * 20 = → Predicted: 168.55, Actual: 1740.0
# 22 / 2 = → Predicted: 11.32, Actual: 11.0
# 1 - 53 = → Predicted: -57.77, Actual: -52.0
# 39 + 73 = → Predicted: 111.56, Actual: 112.0
# 94 + 51 = → Predicted: 145.67, Actual: 145.0
# 3 + 14 = → Predicted: 19.54, Actual: 17.0
# 58 * 19 = → Predicted: 168.55, Actual: 1102.0
# 24 + 5 = → Predicted: 28.02, Actual: 29.0
# 12 + 80 = → Predicted: 89.41, Actual: 92.0
# 25 + 44 = → Predicted: 67.83, Actual: 69.0
# 65 * 100 = → Predicted: 168.56, Actual: 6500.0
# 31 + 77 = → Predicted: 106.01, Actual: 108.0
# 94 + 95 = → Predicted: 167.24, Actual: 189.0
# 35 - 54 = → Predicted: -20.52, Actual: -19.0
# 57 / 57 = → Predicted: 0.54, Actual: 1.0
# 44 * 97 = → Predicted: 168.55, Actual: 4268.0
# 37 / 37 = → Predicted: 0.28, Actual: 1.0
# 65 - 29 = → Predicted: 34.61, Actual: 36.0
# 50 - 49 = → Predicted: -0.04, Actual: 1.0
# 1 * 40 = → Predicted: 168.26, Actual: 40.0
# 59 / 1 = → Predicted: 58.82, Actual: 59.0
# 33 + 34 = → Predicted: 65.36, Actual: 67.0
# 60 * 10 = → Predicted: 168.54, Actual: 600.0
# 48 * 19 = → Predicted: 168.55, Actual: 912.0
# 61 * 26 = → Predicted: 168.56, Actual: 1586.0
# 91 - 2 = → Predicted: 87.19, Actual: 89.0
# 10 / 1 = → Predicted: 8.79, Actual: 10.0
# 81 * 94 = → Predicted: 168.56, Actual: 7614.0
# 94 * 22 = → Predicted: 168.56, Actual: 2068.0
# 23 - 70 = → Predicted: -49.56, Actual: -47.0
# 12 / 4 = → Predicted: 3.87, Actual: 3.0
# 90 - 93 = → Predicted: -2.64, Actual: -3.0
# 64 / 32 = → Predicted: 3.30, Actual: 2.0
# 32 / 4 = → Predicted: 8.56, Actual: 8.0
# 33 * 81 = → Predicted: 168.55, Actual: 2673.0
# 77 / 77 = → Predicted: 0.83, Actual: 1.0
# 72 / 3 = → Predicted: 24.39, Actual: 24.0
# 23 * 34 = → Predicted: 168.54, Actual: 782.0
# 41 - 46 = → Predicted: -5.05, Actual: -5.0
# 86 - 63 = → Predicted: 24.42, Actual: 23.0
# 3 / 1 = → Predicted: 2.88, Actual: 3.0
# 51 / 51 = → Predicted: 0.91, Actual: 1.0
# 93 / 31 = → Predicted: 4.19, Actual: 3.0
# 99 * 90 = → Predicted: 168.56, Actual: 8910.0
# 75 / 3 = → Predicted: 25.20, Actual: 25.0
# 15 * 10 = → Predicted: 168.50, Actual: 150.0
# 55 * 91 = → Predicted: 168.55, Actual: 5005.0
# 33 / 3 = → Predicted: 10.42, Actual: 11.0
# 50 / 2 = → Predicted: 24.68, Actual: 25.0
# 36 / 6 = → Predicted: 6.17, Actual: 6.0
# 79 - 9 = → Predicted: 69.95, Actual: 70.0
# 82 * 99 = → Predicted: 168.56, Actual: 8118.0
# 69 * 25 = → Predicted: 168.56, Actual: 1725.0
# 12 - 68 = → Predicted: -56.58, Actual: -56.0
# 11 / 1 = → Predicted: 11.12, Actual: 11.0
# 12 + 13 = → Predicted: 20.71, Actual: 25.0
# 32 + 50 = → Predicted: 81.19, Actual: 82.0
# 7 * 69 = → Predicted: 168.50, Actual: 483.0
# 83 * 74 = → Predicted: 168.56, Actual: 6142.0
# 21 + 24 = → Predicted: 46.66, Actual: 45.0
# 70 / 35 = → Predicted: 0.91, Actual: 2.0
# 28 * 40 = → Predicted: 168.55, Actual: 1120.0
# 42 / 14 = → Predicted: 2.30, Actual: 3.0
# 90 - 52 = → Predicted: 39.19, Actual: 38.0
# 40 * 18 = → Predicted: 168.55, Actual: 720.0
# 63 * 30 = → Predicted: 168.55, Actual: 1890.0
# 69 / 69 = → Predicted: 0.89, Actual: 1.0
# 57 / 19 = → Predicted: 3.98, Actual: 3.0
# 43 * 99 = → Predicted: 168.55, Actual: 4257.0
# 51 - 51 = → Predicted: -1.30, Actual: 0.0
# 19 * 35 = → Predicted: 168.54, Actual: 665.0
# 45 + 34 = → Predicted: 76.45, Actual: 79.0
# 73 - 47 = → Predicted: 24.15, Actual: 26.0
# 36 * 82 = → Predicted: 168.55, Actual: 2952.0
# 16 - 49 = → Predicted: -33.90, Actual: -33.0
# 13 * 57 = → Predicted: 168.50, Actual: 741.0
# 64 - 10 = → Predicted: 55.76, Actual: 54.0
# 78 * 90 = → Predicted: 168.56, Actual: 7020.0
# 86 * 67 = → Predicted: 168.56, Actual: 5762.0
# 60 / 5 = → Predicted: 12.00, Actual: 12.0
# 80 * 33 = → Predicted: 168.56, Actual: 2640.0
# 87 + 22 = → Predicted: 107.46, Actual: 109.0
# 88 + 94 = → Predicted: 166.82, Actual: 182.0
# 80 + 86 = → Predicted: 165.16, Actual: 166.0
# 39 * 52 = → Predicted: 168.55, Actual: 2028.0
# 35 * 48 = → Predicted: 168.55, Actual: 1680.0
# 95 / 5 = → Predicted: 17.75, Actual: 19.0
# 65 * 54 = → Predicted: 168.56, Actual: 3510.0
# 38 * 76 = → Predicted: 168.55, Actual: 2888.0
# 52 + 11 = → Predicted: 62.78, Actual: 63.0
# 21 / 7 = → Predicted: 3.65, Actual: 3.0
# 46 * 75 = → Predicted: 168.55, Actual: 3450.0
# 21 - 11 = → Predicted: 9.32, Actual: 10.0
# 58 - 31 = → Predicted: 25.88, Actual: 27.0
# 6 + 15 = → Predicted: 24.74, Actual: 21.0
# 6 / 6 = → Predicted: 2.02, Actual: 1.0
# 14 - 49 = → Predicted: -36.90, Actual: -35.0
# 84 + 49 = → Predicted: 131.36, Actual: 133.0
# 54 * 13 = → Predicted: 168.55, Actual: 702.0
# 37 - 31 = → Predicted: 5.12, Actual: 6.0
# 40 * 80 = → Predicted: 168.55, Actual: 3200.0
# 74 + 48 = → Predicted: 120.51, Actual: 122.0
# 14 + 3 = → Predicted: 17.20, Actual: 17.0
# 43 - 25 = → Predicted: 18.14, Actual: 18.0
# 18 / 18 = → Predicted: 0.94, Actual: 1.0
# 19 * 22 = → Predicted: 168.54, Actual: 418.0
# 45 - 63 = → Predicted: -17.77, Actual: -18.0
# 79 / 79 = → Predicted: 1.13, Actual: 1.0
# 9 - 23 = → Predicted: -14.44, Actual: -14.0
# 7 + 63 = → Predicted: 67.72, Actual: 70.0
# 74 + 60 = → Predicted: 133.28, Actual: 134.0
# 66 * 12 = → Predicted: 168.55, Actual: 792.0
# 87 / 87 = → Predicted: 1.19, Actual: 1.0
# 46 * 13 = → Predicted: 168.54, Actual: 598.0
# 49 - 42 = → Predicted: 5.24, Actual: 7.0
# 18 / 3 = → Predicted: 5.86, Actual: 6.0
# 31 * 34 = → Predicted: 168.55, Actual: 1054.0
# 29 + 20 = → Predicted: 48.84, Actual: 49.0
# 78 - 14 = → Predicted: 63.43, Actual: 64.0
# 63 * 13 = → Predicted: 168.55, Actual: 819.0
# 48 - 42 = → Predicted: 3.97, Actual: 6.0
# 13 - 33 = → Predicted: -18.30, Actual: -20.0
# 16 * 47 = → Predicted: 168.51, Actual: 752.0
# 5 / 5 = → Predicted: -0.69, Actual: 1.0
# 28 / 7 = → Predicted: 4.81, Actual: 4.0
# 25 * 50 = → Predicted: 168.55, Actual: 1250.0
# 34 / 17 = → Predicted: 2.12, Actual: 2.0
# 88 / 8 = → Predicted: 9.56, Actual: 11.0
# 62 + 86 = → Predicted: 147.79, Actual: 148.0
# 61 + 88 = → Predicted: 148.40, Actual: 149.0
# 42 - 55 = → Predicted: -13.92, Actual: -13.0
# 8 + 77 = → Predicted: 83.32, Actual: 85.0
# 30 * 84 = → Predicted: 168.55, Actual: 2520.0
# 60 * 63 = → Predicted: 168.56, Actual: 3780.0
# 3 + 47 = → Predicted: 47.71, Actual: 50.0
# 99 + 10 = → Predicted: 109.02, Actual: 109.0
# 93 + 64 = → Predicted: 158.74, Actual: 157.0
# 18 / 9 = → Predicted: 1.06, Actual: 2.0
# 33 + 36 = → Predicted: 68.95, Actual: 69.0
# 57 + 45 = → Predicted: 100.97, Actual: 102.0
# 85 / 17 = → Predicted: 6.50, Actual: 5.0
# 50 - 16 = → Predicted: 34.14, Actual: 34.0
# 29 * 28 = → Predicted: 168.55, Actual: 812.0
# 96 - 91 = → Predicted: 2.87, Actual: 5.0
# 6 - 69 = → Predicted: -65.03, Actual: -63.0
# 24 - 89 = → Predicted: -66.68, Actual: -65.0
# 12 - 9 = → Predicted: 4.16, Actual: 3.0
# 17 + 11 = → Predicted: 27.82, Actual: 28.0
# 71 + 84 = → Predicted: 155.97, Actual: 155.0
# 27 + 7 = → Predicted: 28.82, Actual: 34.0
# 93 / 3 = → Predicted: 29.66, Actual: 31.0
# 3 - 55 = → Predicted: -55.19, Actual: -52.0
# 1 - 47 = → Predicted: -50.16, Actual: -46.0
# 28 / 7 = → Predicted: 4.81, Actual: 4.0
# 59 / 59 = → Predicted: -0.01, Actual: 1.0
# 41 + 60 = → Predicted: 100.48, Actual: 101.0
# 19 / 1 = → Predicted: 19.34, Actual: 19.0
# 24 + 73 = → Predicted: 97.54, Actual: 97.0
# 88 * 84 = → Predicted: 168.56, Actual: 7392.0
# 22 + 64 = → Predicted: 88.24, Actual: 86.0
# 81 / 3 = → Predicted: 27.15, Actual: 27.0
# 30 / 2 = → Predicted: 14.33, Actual: 15.0
# 18 + 22 = → Predicted: 41.06, Actual: 40.0
# 53 / 1 = → Predicted: 51.96, Actual: 53.0
# 56 + 41 = → Predicted: 96.26, Actual: 97.0
# 59 - 31 = → Predicted: 26.61, Actual: 28.0
# 60 * 31 = → Predicted: 168.55, Actual: 1860.0
# 96 * 69 = → Predicted: 168.56, Actual: 6624.0
# 92 - 56 = → Predicted: 34.85, Actual: 36.0
# 45 + 59 = → Predicted: 104.47, Actual: 104.0
# 61 - 47 = → Predicted: 11.44, Actual: 14.0
# 13 - 86 = → Predicted: -71.07, Actual: -73.0
# 70 / 14 = → Predicted: 4.85, Actual: 5.0
# 75 * 8 = → Predicted: 168.55, Actual: 600.0
# 47 + 40 = → Predicted: 86.21, Actual: 87.0
# 44 + 63 = → Predicted: 107.66, Actual: 107.0
# 68 / 1 = → Predicted: 66.25, Actual: 68.0
# 83 + 21 = → Predicted: 104.91, Actual: 104.0
# 54 * 71 = → Predicted: 168.56, Actual: 3834.0
# 39 / 1 = → Predicted: 37.62, Actual: 39.0
# 85 + 37 = → Predicted: 122.70, Actual: 122.0
# 43 / 43 = → Predicted: 0.97, Actual: 1.0
# 9 - 63 = → Predicted: -54.50, Actual: -54.0
# 26 * 43 = → Predicted: 168.54, Actual: 1118.0
# 58 - 94 = → Predicted: -36.53, Actual: -36.0
# 84 / 21 = → Predicted: 4.27, Actual: 4.0
# 15 * 54 = → Predicted: 168.52, Actual: 810.0
# 100 / 5 = → Predicted: 18.31, Actual: 20.0
# 37 * 89 = → Predicted: 168.55, Actual: 3293.0
# 79 - 93 = → Predicted: -14.41, Actual: -14.0
# 80 / 40 = → Predicted: 0.93, Actual: 2.0
# 93 - 59 = → Predicted: 33.09, Actual: 34.0
# 56 + 1 = → Predicted: 57.51, Actual: 57.0
# 15 / 1 = → Predicted: 14.05, Actual: 15.0
# 86 * 51 = → Predicted: 168.56, Actual: 4386.0
# 33 * 75 = → Predicted: 168.55, Actual: 2475.0
# 92 / 2 = → Predicted: 45.75, Actual: 46.0
# 13 / 13 = → Predicted: -0.67, Actual: 1.0
# 91 * 27 = → Predicted: 168.56, Actual: 2457.0
# 32 / 1 = → Predicted: 31.81, Actual: 32.0
# 64 - 91 = → Predicted: -27.98, Actual: -27.0
# 100 / 100 = → Predicted: 2.00, Actual: 1.0
# 30 - 85 = → Predicted: -54.61, Actual: -55.0
# 80 + 45 = → Predicted: 125.55, Actual: 125.0
# 98 - 49 = → Predicted: 47.37, Actual: 49.0
# 18 - 10 = → Predicted: 8.88, Actual: 8.0
# 70 - 28 = → Predicted: 42.64, Actual: 42.0
# 28 + 15 = → Predicted: 42.56, Actual: 43.0
# 46 + 4 = → Predicted: 49.20, Actual: 50.0
# 97 + 41 = → Predicted: 137.10, Actual: 138.0
# 55 / 1 = → Predicted: 54.10, Actual: 55.0
# 38 + 55 = → Predicted: 91.41, Actual: 93.0
# 57 + 42 = → Predicted: 99.54, Actual: 99.0
# 92 - 19 = → Predicted: 72.78, Actual: 73.0
# 46 / 2 = → Predicted: 22.07, Actual: 23.0
# 56 + 48 = → Predicted: 102.43, Actual: 104.0
# 53 + 8 = → Predicted: 60.55, Actual: 61.0
# 30 / 1 = → Predicted: 28.34, Actual: 30.0
# 66 - 63 = → Predicted: 3.56, Actual: 3.0
# 98 - 85 = → Predicted: 11.17, Actual: 13.0
# 81 + 5 = → Predicted: 85.42, Actual: 86.0
# 58 - 23 = → Predicted: 33.54, Actual: 35.0
# 58 * 52 = → Predicted: 168.56, Actual: 3016.0
# 16 - 35 = → Predicted: -18.18, Actual: -19.0
# 88 * 78 = → Predicted: 168.56, Actual: 6864.0
# 63 + 88 = → Predicted: 148.89, Actual: 151.0
# 81 - 44 = → Predicted: 36.31, Actual: 37.0
# 33 - 31 = → Predicted: 0.89, Actual: 2.0
# 72 / 3 = → Predicted: 24.39, Actual: 24.0
# 65 + 36 = → Predicted: 101.54, Actual: 101.0
# 2 / 2 = → Predicted: -0.34, Actual: 1.0
# 21 + 32 = → Predicted: 53.45, Actual: 53.0
# 29 - 38 = → Predicted: -9.06, Actual: -9.0
# 80 - 85 = → Predicted: -6.79, Actual: -5.0
# 12 * 41 = → Predicted: 168.53, Actual: 492.0
# 16 + 61 = → Predicted: 76.92, Actual: 77.0
# 62 / 62 = → Predicted: 0.44, Actual: 1.0
# 7 * 48 = → Predicted: 168.50, Actual: 336.0
# 50 * 26 = → Predicted: 168.55, Actual: 1300.0
# 66 / 66 = → Predicted: 1.06, Actual: 1.0
# 83 + 14 = → Predicted: 95.80, Actual: 97.0
# 95 + 75 = → Predicted: 166.07, Actual: 170.0
# 21 - 40 = → Predicted: -20.62, Actual: -19.0
# 77 / 77 = → Predicted: 0.83, Actual: 1.0
# 57 / 19 = → Predicted: 3.98, Actual: 3.0
# 27 - 69 = → Predicted: -43.02, Actual: -42.0
# 75 / 15 = → Predicted: 6.23, Actual: 5.0
# 77 + 85 = → Predicted: 162.71, Actual: 162.0
# 96 + 4 = → Predicted: 101.00, Actual: 100.0
# 78 / 1 = → Predicted: 76.85, Actual: 78.0
# 33 * 64 = → Predicted: 168.55, Actual: 2112.0
# 100 / 25 = → Predicted: 3.03, Actual: 4.0
# 87 / 87 = → Predicted: 1.19, Actual: 1.0
# 14 - 94 = → Predicted: -79.02, Actual: -80.0
# 53 / 53 = → Predicted: 0.78, Actual: 1.0
# 93 - 94 = → Predicted: -1.68, Actual: -1.0
# 56 - 27 = → Predicted: 27.79, Actual: 29.0
# 84 - 84 = → Predicted: -1.34, Actual: 0.0
# 30 - 49 = → Predicted: -20.53, Actual: -19.0
# 97 - 31 = → Predicted: 65.44, Actual: 66.0
# 64 - 83 = → Predicted: -18.89, Actual: -19.0
# 99 - 42 = → Predicted: 55.51, Actual: 57.0
# 6 - 48 = → Predicted: -44.07, Actual: -42.0
# 68 - 10 = → Predicted: 59.36, Actual: 58.0
# 51 * 37 = → Predicted: 168.55, Actual: 1887.0
# 97 / 97 = → Predicted: 1.41, Actual: 1.0
# 44 / 2 = → Predicted: 21.20, Actual: 22.0
# 19 - 25 = → Predicted: -6.43, Actual: -6.0
# 32 / 32 = → Predicted: 0.25, Actual: 1.0
# 77 * 34 = → Predicted: 168.56, Actual: 2618.0
# 5 + 17 = → Predicted: 22.53, Actual: 22.0
# 96 / 1 = → Predicted: 95.74, Actual: 96.0
# 7 * 26 = → Predicted: 168.49, Actual: 182.0
# 7 + 14 = → Predicted: 23.72, Actual: 21.0
# 89 - 27 = → Predicted: 60.27, Actual: 62.0
# 95 / 95 = → Predicted: 1.25, Actual: 1.0
# 49 + 41 = → Predicted: 88.34, Actual: 90.0
# 88 * 20 = → Predicted: 168.55, Actual: 1760.0
# 1 * 31 = → Predicted: 168.22, Actual: 31.0
# 17 + 99 = → Predicted: 116.90, Actual: 116.0
# 67 * 9 = → Predicted: 168.55, Actual: 603.0
# 9 * 67 = → Predicted: 168.50, Actual: 603.0
# 81 - 23 = → Predicted: 56.86, Actual: 58.0
# 79 / 1 = → Predicted: 78.55, Actual: 79.0
# 55 + 35 = → Predicted: 91.12, Actual: 90.0
# 83 * 79 = → Predicted: 168.56, Actual: 6557.0
# 22 - 14 = → Predicted: 7.54, Actual: 8.0
# 50 * 94 = → Predicted: 168.55, Actual: 4700.0
# 45 - 21 = → Predicted: 23.36, Actual: 24.0
# 66 - 95 = → Predicted: -29.48, Actual: -29.0
# 33 / 1 = → Predicted: 31.73, Actual: 33.0
# 12 - 76 = → Predicted: -64.59, Actual: -64.0
# 52 / 2 = → Predicted: 25.34, Actual: 26.0
# 79 - 72 = → Predicted: 8.25, Actual: 7.0
# 31 * 74 = → Predicted: 168.55, Actual: 2294.0
# 72 + 43 = → Predicted: 114.30, Actual: 115.0
# 78 - 72 = → Predicted: 7.35, Actual: 6.0
# 16 / 4 = → Predicted: 6.33, Actual: 4.0
# 55 / 5 = → Predicted: 11.04, Actual: 11.0
# 2 - 7 = → Predicted: -2.17, Actual: -5.0
# 57 - 29 = → Predicted: 26.80, Actual: 28.0
# 97 / 1 = → Predicted: 96.48, Actual: 97.0
# 58 / 29 = → Predicted: 3.30, Actual: 2.0
# 87 * 11 = → Predicted: 168.55, Actual: 957.0
# 9 - 47 = → Predicted: -38.65, Actual: -38.0
# 77 - 15 = → Predicted: 59.39, Actual: 62.0
# 80 * 85 = → Predicted: 168.56, Actual: 6800.0
# 39 / 13 = → Predicted: 4.20, Actual: 3.0
# 32 - 14 = → Predicted: 17.29, Actual: 18.0
# 46 / 23 = → Predicted: 2.72, Actual: 2.0
# 16 - 43 = → Predicted: -27.91, Actual: -27.0
# 90 * 44 = → Predicted: 168.56, Actual: 3960.0
# 38 * 5 = → Predicted: 168.49, Actual: 190.0
# 70 + 68 = → Predicted: 137.38, Actual: 138.0
# 49 - 51 = → Predicted: -2.85, Actual: -2.0
# 75 / 5 = → Predicted: 14.54, Actual: 15.0
# 17 / 1 = → Predicted: 16.68, Actual: 17.0
# 74 - 59 = → Predicted: 15.68, Actual: 15.0
# 55 + 88 = → Predicted: 142.46, Actual: 143.0
# 39 - 72 = → Predicted: -32.54, Actual: -33.0
# 56 * 6 = → Predicted: 168.55, Actual: 336.0
# 59 / 59 = → Predicted: -0.01, Actual: 1.0
# 5 / 1 = → Predicted: 4.54, Actual: 5.0
# 68 + 24 = → Predicted: 91.04, Actual: 92.0
# 58 + 11 = → Predicted: 68.93, Actual: 69.0
# 91 + 31 = → Predicted: 117.70, Actual: 122.0
# 98 - 8 = → Predicted: 90.11, Actual: 90.0
# 25 * 7 = → Predicted: 168.53, Actual: 175.0
# 72 * 51 = → Predicted: 168.56, Actual: 3672.0
# 89 * 24 = → Predicted: 168.56, Actual: 2136.0
# 24 + 97 = → Predicted: 119.46, Actual: 121.0
# 93 - 94 = → Predicted: -1.68, Actual: -1.0
# 37 - 52 = → Predicted: -15.30, Actual: -15.0
# 56 / 8 = → Predicted: 6.42, Actual: 7.0
# 62 / 2 = → Predicted: 30.91, Actual: 31.0
# 7 * 24 = → Predicted: 168.49, Actual: 168.0
# 51 - 64 = → Predicted: -12.27, Actual: -13.0
# 10 + 77 = → Predicted: 85.82, Actual: 87.0
# 97 + 19 = → Predicted: 114.87, Actual: 116.0
# 93 + 98 = → Predicted: 167.21, Actual: 191.0
# 37 + 79 = → Predicted: 115.65, Actual: 116.0
# 85 + 42 = → Predicted: 125.67, Actual: 127.0
# 60 * 28 = → Predicted: 168.55, Actual: 1680.0
# 98 * 66 = → Predicted: 168.56, Actual: 6468.0
# 13 + 60 = → Predicted: 73.45, Actual: 73.0
# 20 * 22 = → Predicted: 168.54, Actual: 440.0
# 63 - 23 = → Predicted: 38.59, Actual: 40.0
# 37 / 37 = → Predicted: 0.28, Actual: 1.0
# 62 * 100 = → Predicted: 168.56, Actual: 6200.0
# 66 - 36 = → Predicted: 29.47, Actual: 30.0
# 73 / 73 = → Predicted: 0.72, Actual: 1.0
# 78 / 26 = → Predicted: 4.42, Actual: 3.0
# 36 * 24 = → Predicted: 168.55, Actual: 864.0
# 48 - 14 = → Predicted: 32.38, Actual: 34.0
# 66 + 4 = → Predicted: 70.53, Actual: 70.0
# 9 + 88 = → Predicted: 96.17, Actual: 97.0
# 1 + 92 = → Predicted: 92.76, Actual: 93.0
# 25 / 1 = → Predicted: 24.69, Actual: 25.0
# 27 + 7 = → Predicted: 28.82, Actual: 34.0
# 57 + 25 = → Predicted: 81.83, Actual: 82.0
# 64 - 21 = → Predicted: 42.47, Actual: 43.0
# 19 - 8 = → Predicted: 9.34, Actual: 11.0
# 22 * 10 = → Predicted: 168.53, Actual: 220.0
# 94 - 13 = → Predicted: 81.59, Actual: 81.0
# 20 / 10 = → Predicted: 0.55, Actual: 2.0
# 36 / 9 = → Predicted: 4.24, Actual: 4.0
# 76 * 2 = → Predicted: 163.65, Actual: 152.0
# 65 - 7 = → Predicted: 59.22, Actual: 58.0
# 1 - 12 = → Predicted: -13.06, Actual: -11.0
# 7 * 54 = → Predicted: 168.50, Actual: 378.0
# 11 * 96 = → Predicted: 168.53, Actual: 1056.0
# 19 + 70 = → Predicted: 88.85, Actual: 89.0
# 59 - 10 = → Predicted: 49.90, Actual: 49.0
# 88 / 11 = → Predicted: 7.65, Actual: 8.0
# 67 * 39 = → Predicted: 168.56, Actual: 2613.0
# 42 - 87 = → Predicted: -44.61, Actual: -45.0
# 36 + 74 = → Predicted: 108.49, Actual: 110.0
# 67 / 67 = → Predicted: 1.17, Actual: 1.0
# 24 * 4 = → Predicted: 168.50, Actual: 96.0
# 81 / 9 = → Predicted: 8.12, Actual: 9.0
# 47 - 77 = → Predicted: -31.78, Actual: -30.0
# 16 / 1 = → Predicted: 15.79, Actual: 16.0
# 16 * 30 = → Predicted: 168.51, Actual: 480.0
# 23 / 23 = → Predicted: 0.25, Actual: 1.0
# 73 - 13 = → Predicted: 60.75, Actual: 60.0
# 35 - 90 = → Predicted: -54.90, Actual: -55.0
# 32 * 47 = → Predicted: 168.55, Actual: 1504.0
# 50 / 50 = → Predicted: 0.73, Actual: 1.0
# 26 * 20 = → Predicted: 168.54, Actual: 520.0
# 57 * 77 = → Predicted: 168.56, Actual: 4389.0
# 6 - 80 = → Predicted: -72.48, Actual: -74.0
# 48 - 93 = → Predicted: -45.78, Actual: -45.0
# 81 / 1 = → Predicted: 80.01, Actual: 81.0
# 18 - 64 = → Predicted: -45.95, Actual: -46.0
# 38 / 2 = → Predicted: 18.68, Actual: 19.0
# 1 * 11 = → Predicted: 167.96, Actual: 11.0
# 5 - 22 = → Predicted: -13.64, Actual: -17.0
# 11 + 90 = → Predicted: 100.96, Actual: 101.0
# 56 / 28 = → Predicted: 2.05, Actual: 2.0
# 99 / 33 = → Predicted: 2.34, Actual: 3.0
# 91 - 38 = → Predicted: 51.83, Actual: 53.0
# 100 + 47 = → Predicted: 148.54, Actual: 147.0
# 56 - 90 = → Predicted: -33.82, Actual: -34.0
# 22 / 1 = → Predicted: 21.53, Actual: 22.0
# 8 / 1 = → Predicted: 8.23, Actual: 8.0
# 21 / 1 = → Predicted: 21.13, Actual: 21.0
# 4 - 4 = → Predicted: 2.36, Actual: 0.0
# 19 / 19 = → Predicted: -0.14, Actual: 1.0
# 85 / 5 = → Predicted: 16.22, Actual: 17.0
# 84 / 4 = → Predicted: 19.17, Actual: 21.0
# 92 + 49 = → Predicted: 139.66, Actual: 141.0
# 40 - 38 = → Predicted: 1.07, Actual: 2.0
# 37 - 62 = → Predicted: -24.94, Actual: -25.0
# 23 * 7 = → Predicted: 168.52, Actual: 161.0
# 46 + 82 = → Predicted: 127.49, Actual: 128.0
# 87 - 9 = → Predicted: 77.23, Actual: 78.0
# 51 - 78 = → Predicted: -27.42, Actual: -27.0
# 11 - 87 = → Predicted: -74.13, Actual: -76.0
# 17 / 17 = → Predicted: 0.44, Actual: 1.0
# 52 + 18 = → Predicted: 70.92, Actual: 70.0
# 9 - 33 = → Predicted: -24.97, Actual: -24.0
# 27 / 3 = → Predicted: 8.78, Actual: 9.0
# 82 - 54 = → Predicted: 28.44, Actual: 28.0
# 93 / 1 = → Predicted: 91.74, Actual: 93.0
# 48 + 21 = → Predicted: 67.55, Actual: 69.0
# 49 + 72 = → Predicted: 121.41, Actual: 121.0
# 65 - 55 = → Predicted: 10.14, Actual: 10.0
# 43 + 50 = → Predicted: 93.72, Actual: 93.0
# 56 / 1 = → Predicted: 55.56, Actual: 56.0
# 27 - 98 = → Predicted: -72.17, Actual: -71.0
# 57 * 23 = → Predicted: 168.55, Actual: 1311.0
# 91 / 13 = → Predicted: 10.68, Actual: 7.0
# 76 - 31 = → Predicted: 44.42, Actual: 45.0
# 18 - 48 = → Predicted: -31.61, Actual: -30.0
# 21 / 1 = → Predicted: 21.13, Actual: 21.0
# 92 * 89 = → Predicted: 168.56, Actual: 8188.0
# 34 / 34 = → Predicted: -0.68, Actual: 1.0
# 46 * 11 = → Predicted: 168.55, Actual: 506.0
# 73 - 62 = → Predicted: 12.06, Actual: 11.0
# 98 / 7 = → Predicted: 12.76, Actual: 14.0
# 42 * 50 = → Predicted: 168.55, Actual: 2100.0
# 45 - 49 = → Predicted: -4.73, Actual: -4.0
# 33 / 1 = → Predicted: 31.73, Actual: 33.0
# 96 + 54 = → Predicted: 151.58, Actual: 150.0
# 25 / 25 = → Predicted: -1.47, Actual: 1.0
# 16 - 34 = → Predicted: -17.92, Actual: -18.0
# 68 / 34 = → Predicted: 1.62, Actual: 2.0
# 4 + 2 = → Predicted: 14.87, Actual: 6.0
# 64 + 61 = → Predicted: 123.87, Actual: 125.0
# 87 * 85 = → Predicted: 168.56, Actual: 7395.0
# 45 + 47 = → Predicted: 90.03, Actual: 92.0
# 95 - 67 = → Predicted: 26.81, Actual: 28.0
# 23 / 23 = → Predicted: 0.25, Actual: 1.0
# 88 * 6 = → Predicted: 168.55, Actual: 528.0
# 58 * 48 = → Predicted: 168.56, Actual: 2784.0
# 30 + 28 = → Predicted: 59.64, Actual: 58.0
# 28 / 14 = → Predicted: 1.40, Actual: 2.0
# 87 * 71 = → Predicted: 168.56, Actual: 6177.0
# 98 - 15 = → Predicted: 81.74, Actual: 83.0
# 10 + 72 = → Predicted: 81.18, Actual: 82.0
# 32 + 95 = → Predicted: 126.51, Actual: 127.0
# 96 * 84 = → Predicted: 168.56, Actual: 8064.0
# 42 + 23 = → Predicted: 64.62, Actual: 65.0
# 63 / 7 = → Predicted: 10.91, Actual: 9.0
# 13 - 75 = → Predicted: -58.41, Actual: -62.0
# 42 + 57 = → Predicted: 99.60, Actual: 99.0
# 6 + 50 = → Predicted: 54.47, Actual: 56.0
# 25 + 99 = → Predicted: 125.47, Actual: 124.0
# 82 + 86 = → Predicted: 165.71, Actual: 168.0
# 47 * 54 = → Predicted: 168.55, Actual: 2538.0
# 5 / 1 = → Predicted: 4.54, Actual: 5.0
# 7 + 76 = → Predicted: 82.02, Actual: 83.0
# 29 + 55 = → Predicted: 82.28, Actual: 84.0
# 63 - 71 = → Predicted: -8.01, Actual: -8.0
# 98 / 7 = → Predicted: 12.76, Actual: 14.0
# 91 / 91 = → Predicted: 2.17, Actual: 1.0
# 97 + 63 = → Predicted: 162.05, Actual: 160.0
# 69 * 43 = → Predicted: 168.56, Actual: 2967.0
# 73 + 78 = → Predicted: 149.57, Actual: 151.0
# 91 - 44 = → Predicted: 46.22, Actual: 47.0
# 4 - 93 = → Predicted: -88.37, Actual: -89.0
# 26 - 72 = → Predicted: -44.88, Actual: -46.0
# 59 / 1 = → Predicted: 58.82, Actual: 59.0
# 70 + 51 = → Predicted: 119.53, Actual: 121.0
# 62 + 75 = → Predicted: 137.44, Actual: 137.0
# 73 + 11 = → Predicted: 81.75, Actual: 84.0
# 31 / 31 = → Predicted: -0.38, Actual: 1.0
# 51 + 80 = → Predicted: 131.17, Actual: 131.0
# 69 / 69 = → Predicted: 0.89, Actual: 1.0
# 34 + 80 = → Predicted: 113.94, Actual: 114.0
# 68 - 73 = → Predicted: -5.69, Actual: -5.0
# 10 + 14 = → Predicted: 25.32, Actual: 24.0
# 40 + 92 = → Predicted: 131.31, Actual: 132.0
# 73 + 90 = → Predicted: 162.22, Actual: 163.0
# 56 / 2 = → Predicted: 27.47, Actual: 28.0
# 92 * 74 = → Predicted: 168.56, Actual: 6808.0
# 38 + 36 = → Predicted: 73.02, Actual: 74.0
# 51 + 39 = → Predicted: 92.74, Actual: 90.0
# 30 - 28 = → Predicted: 2.49, Actual: 2.0
# 30 * 49 = → Predicted: 168.55, Actual: 1470.0
# 61 + 88 = → Predicted: 148.40, Actual: 149.0
# 8 / 1 = → Predicted: 8.23, Actual: 8.0
# 52 * 59 = → Predicted: 168.56, Actual: 3068.0
# 65 + 28 = → Predicted: 93.86, Actual: 93.0
# 72 - 16 = → Predicted: 56.19, Actual: 56.0
# 66 / 22 = → Predicted: 3.75, Actual: 3.0
# 44 * 79 = → Predicted: 168.55, Actual: 3476.0
# 33 + 31 = → Predicted: 65.77, Actual: 64.0
# 91 * 47 = → Predicted: 168.56, Actual: 4277.0
# 5 - 89 = → Predicted: -86.15, Actual: -84.0
# 61 / 61 = → Predicted: 0.26, Actual: 1.0
# 56 - 58 = → Predicted: -1.87, Actual: -2.0
# 51 / 3 = → Predicted: 16.95, Actual: 17.0
# 47 / 1 = → Predicted: 46.70, Actual: 47.0
# 76 * 54 = → Predicted: 168.56, Actual: 4104.0
# 95 / 95 = → Predicted: 1.25, Actual: 1.0
# 48 * 23 = → Predicted: 168.55, Actual: 1104.0
# 39 / 1 = → Predicted: 37.62, Actual: 39.0
# 21 * 55 = → Predicted: 168.54, Actual: 1155.0
# 52 * 99 = → Predicted: 168.56, Actual: 5148.0
# 51 / 51 = → Predicted: 0.91, Actual: 1.0
# 49 + 42 = → Predicted: 91.32, Actual: 91.0
# 68 * 45 = → Predicted: 168.56, Actual: 3060.0
# 7 + 62 = → Predicted: 71.48, Actual: 69.0
# 85 - 33 = → Predicted: 50.39, Actual: 52.0
# 50 - 35 = → Predicted: 16.20, Actual: 15.0
# 40 + 5 = → Predicted: 45.56, Actual: 45.0
# 17 / 1 = → Predicted: 16.68, Actual: 17.0
# 99 + 76 = → Predicted: 166.96, Actual: 175.0
# 50 - 88 = → Predicted: -37.60, Actual: -38.0
# 17 / 1 = → Predicted: 16.68, Actual: 17.0
# 48 + 91 = → Predicted: 138.82, Actual: 139.0
# 32 - 21 = → Predicted: 10.53, Actual: 11.0
# 20 - 18 = → Predicted: 2.42, Actual: 2.0
# 94 + 40 = → Predicted: 134.58, Actual: 134.0
# 7 / 7 = → Predicted: -0.04, Actual: 1.0
# 70 / 2 = → Predicted: 34.97, Actual: 35.0
# 91 * 52 = → Predicted: 168.56, Actual: 4732.0
# 53 + 55 = → Predicted: 107.38, Actual: 108.0
# 28 + 53 = → Predicted: 81.09, Actual: 81.0
# 50 - 67 = → Predicted: -17.25, Actual: -17.0
# 97 / 97 = → Predicted: 1.41, Actual: 1.0
# 95 / 19 = → Predicted: 5.15, Actual: 5.0
# 60 - 97 = → Predicted: -39.29, Actual: -37.0
# 15 * 63 = → Predicted: 168.52, Actual: 945.0
# 60 + 67 = → Predicted: 126.42, Actual: 127.0
# 57 - 39 = → Predicted: 17.61, Actual: 18.0
# 95 - 68 = → Predicted: 26.35, Actual: 27.0
# 49 - 99 = → Predicted: -50.66, Actual: -50.0
# 89 * 46 = → Predicted: 168.56, Actual: 4094.0
# 25 * 80 = → Predicted: 168.55, Actual: 2000.0
# 71 - 82 = → Predicted: -10.36, Actual: -11.0
# 11 + 22 = → Predicted: 34.14, Actual: 33.0
# 80 * 70 = → Predicted: 168.56, Actual: 5600.0
# 72 / 8 = → Predicted: 8.12, Actual: 9.0
# 51 * 47 = → Predicted: 168.55, Actual: 2397.0
# 77 - 26 = → Predicted: 49.08, Actual: 51.0
# 9 * 35 = → Predicted: 168.50, Actual: 315.0
# 41 + 24 = → Predicted: 63.84, Actual: 65.0
# 76 * 88 = → Predicted: 168.56, Actual: 6688.0
# 38 - 32 = → Predicted: 5.14, Actual: 6.0
# 10 + 79 = → Predicted: 90.88, Actual: 89.0
# 100 / 25 = → Predicted: 3.03, Actual: 4.0
# 32 / 8 = → Predicted: 4.03, Actual: 4.0
# 59 - 33 = → Predicted: 25.24, Actual: 26.0
# 21 + 30 = → Predicted: 52.08, Actual: 51.0
# 7 - 51 = → Predicted: -43.74, Actual: -44.0
# 4 * 99 = → Predicted: 168.49, Actual: 396.0
# 10 + 17 = → Predicted: 28.30, Actual: 27.0
# 15 / 15 = → Predicted: -2.62, Actual: 1.0
# 67 + 65 = → Predicted: 130.90, Actual: 132.0
# 91 / 13 = → Predicted: 10.68, Actual: 7.0
# 74 - 81 = → Predicted: -7.66, Actual: -7.0
# 38 / 2 = → Predicted: 18.68, Actual: 19.0
# 16 / 8 = → Predicted: 3.31, Actual: 2.0
# 98 - 79 = → Predicted: 16.90, Actual: 19.0
# 12 / 3 = → Predicted: 4.24, Actual: 4.0
# 52 + 97 = → Predicted: 146.89, Actual: 149.0
# 12 - 32 = → Predicted: -21.38, Actual: -20.0
# 22 * 93 = → Predicted: 168.54, Actual: 2046.0
# 40 + 78 = → Predicted: 118.13, Actual: 118.0
# 64 - 28 = → Predicted: 37.13, Actual: 36.0
# 4 - 73 = → Predicted: -70.87, Actual: -69.0
# 57 + 23 = → Predicted: 80.14, Actual: 80.0
# 10 / 1 = → Predicted: 8.79, Actual: 10.0
# 76 - 64 = → Predicted: 13.63, Actual: 12.0
# 21 / 7 = → Predicted: 3.65, Actual: 3.0
# 89 + 54 = → Predicted: 143.81, Actual: 143.0
# 24 * 24 = → Predicted: 168.52, Actual: 576.0
# 35 + 76 = → Predicted: 110.95, Actual: 111.0
# 44 + 95 = → Predicted: 137.19, Actual: 139.0
# 80 * 74 = → Predicted: 168.56, Actual: 5920.0
# 86 - 51 = → Predicted: 34.55, Actual: 35.0
# 70 + 54 = → Predicted: 123.75, Actual: 124.0
# 67 / 1 = → Predicted: 66.56, Actual: 67.0
# 96 * 22 = → Predicted: 168.56, Actual: 2112.0
# 44 / 44 = → Predicted: 1.70, Actual: 1.0
# 87 / 87 = → Predicted: 1.19, Actual: 1.0
# 44 * 30 = → Predicted: 168.55, Actual: 1320.0
# 76 + 98 = → Predicted: 165.85, Actual: 174.0
# 81 * 59 = → Predicted: 168.56, Actual: 4779.0
# 63 * 23 = → Predicted: 168.55, Actual: 1449.0
# 38 * 15 = → Predicted: 168.55, Actual: 570.0
# 25 - 2 = → Predicted: 23.91, Actual: 23.0
# 3 * 57 = → Predicted: 168.48, Actual: 171.0
# 89 * 24 = → Predicted: 168.56, Actual: 2136.0
# 40 - 66 = → Predicted: -27.36, Actual: -26.0
# 85 * 65 = → Predicted: 168.56, Actual: 5525.0
# 34 + 2 = → Predicted: 29.67, Actual: 36.0
# 29 - 1 = → Predicted: 27.20, Actual: 28.0
# 95 - 25 = → Predicted: 69.24, Actual: 70.0
# 74 + 50 = → Predicted: 124.57, Actual: 124.0
# 15 - 51 = → Predicted: -37.33, Actual: -36.0
# 12 / 6 = → Predicted: 3.01, Actual: 2.0
# 60 * 88 = → Predicted: 168.56, Actual: 5280.0
# 54 * 96 = → Predicted: 168.56, Actual: 5184.0
# 16 - 90 = → Predicted: -74.14, Actual: -74.0
# 25 - 16 = → Predicted: 9.71, Actual: 9.0
# 99 * 34 = → Predicted: 168.56, Actual: 3366.0
# 77 + 37 = → Predicted: 113.51, Actual: 114.0
# 36 * 46 = → Predicted: 168.55, Actual: 1656.0
# 74 / 37 = → Predicted: 2.49, Actual: 2.0
# 45 - 100 = → Predicted: -55.91, Actual: -55.0
# 40 + 67 = → Predicted: 107.67, Actual: 107.0
# 100 - 100 = → Predicted: -6.38, Actual: 0.0
# 49 + 9 = → Predicted: 57.69, Actual: 58.0
# 37 - 90 = → Predicted: -52.52, Actual: -53.0
# 67 / 1 = → Predicted: 66.56, Actual: 67.0
# 94 - 53 = → Predicted: 40.98, Actual: 41.0
# 32 - 76 = → Predicted: -44.92, Actual: -44.0
# 26 * 51 = → Predicted: 168.54, Actual: 1326.0
# 46 - 83 = → Predicted: -36.68, Actual: -37.0
# 91 / 13 = → Predicted: 10.68, Actual: 7.0
# 96 - 1 = → Predicted: 91.40, Actual: 95.0
# 78 + 28 = → Predicted: 103.78, Actual: 106.0
# 91 / 91 = → Predicted: 2.17, Actual: 1.0
# 74 / 37 = → Predicted: 2.49, Actual: 2.0
# 83 / 83 = → Predicted: 0.84, Actual: 1.0
# 63 - 9 = → Predicted: 53.96, Actual: 54.0
# 99 / 11 = → Predicted: 7.99, Actual: 9.0
# 65 / 1 = → Predicted: 64.93, Actual: 65.0
# 59 + 43 = → Predicted: 102.96, Actual: 102.0
# 6 / 2 = → Predicted: 2.64, Actual: 3.0
# 61 * 99 = → Predicted: 168.56, Actual: 6039.0
# 3 - 29 = → Predicted: -26.51, Actual: -26.0
# 52 - 85 = → Predicted: -33.71, Actual: -33.0
# 66 * 93 = → Predicted: 168.56, Actual: 6138.0
# 23 / 23 = → Predicted: 0.25, Actual: 1.0
# 34 + 66 = → Predicted: 99.07, Actual: 100.0
# 21 - 94 = → Predicted: -72.25, Actual: -73.0
# 93 * 94 = → Predicted: 168.56, Actual: 8742.0
# 25 - 27 = → Predicted: -2.02, Actual: -2.0
# 46 + 19 = → Predicted: 64.30, Actual: 65.0
# 97 + 93 = → Predicted: 167.26, Actual: 190.0
# 33 * 35 = → Predicted: 168.55, Actual: 1155.0
# ...
# 37 + 13 = → Predicted: 46.59, Actual: 50.0
# 71 / 71 = → Predicted: 1.03, Actual: 1.0
# 83 / 1 = → Predicted: 82.83, Actual: 83.0
# 21 - 6 = → Predicted: 15.51, Actual: 15.0
# 91 / 1 = → Predicted: 89.74, Actual: 91.0
# 59 + 68 = → Predicted: 126.18, Actual: 127.0
# 7 - 99 = → Predicted: -93.01, Actual: -92.0
# 44 + 88 = → Predicted: 131.68, Actual: 132.0
# 61 / 1 = → Predicted: 60.11, Actual: 61.0
# 5 * 58 = → Predicted: 168.47, Actual: 290.0
# 34 * 94 = → Predicted: 168.55, Actual: 3196.0
# 3 - 29 = → Predicted: -26.51, Actual: -26.0
# 85 + 27 = → Predicted: 111.28, Actual: 112.0
# 42 + 22 = → Predicted: 64.05, Actual: 64.0
# 34 - 99 = → Predicted: -66.30, Actual: -65.0
# 94 + 42 = → Predicted: 135.26, Actual: 136.0
# 14 / 2 = → Predicted: 7.52, Actual: 7.0
# 64 - 24 = → Predicted: 39.11, Actual: 40.0
# 38 - 66 = → Predicted: -28.45, Actual: -28.0
# 85 - 13 = → Predicted: 72.96, Actual: 72.0
# 44 - 98 = → Predicted: -54.67, Actual: -54.0
# 64 - 64 = → Predicted: 1.51, Actual: 0.0
# 5 - 34 = → Predicted: -28.66, Actual: -29.0
# 20 - 3 = → Predicted: 16.84, Actual: 17.0
# 32 / 8 = → Predicted: 4.03, Actual: 4.0
# 50 / 1 = → Predicted: 50.40, Actual: 50.0
# 78 + 13 = → Predicted: 86.59, Actual: 91.0
# 56 / 28 = → Predicted: 2.05, Actual: 2.0
# 34 / 17 = → Predicted: 2.12, Actual: 2.0
# 57 * 43 = → Predicted: 168.56, Actual: 2451.0
# 50 - 13 = → Predicted: 36.32, Actual: 37.0
# 73 + 18 = → Predicted: 91.46, Actual: 91.0
# 7 - 48 = → Predicted: -41.47, Actual: -41.0
# 98 + 27 = → Predicted: 123.74, Actual: 125.0
# 16 * 100 = → Predicted: 168.51, Actual: 1600.0
# 90 - 78 = → Predicted: 13.41, Actual: 12.0
# 37 + 87 = → Predicted: 124.13, Actual: 124.0
# 36 / 36 = → Predicted: 0.56, Actual: 1.0
# 94 + 43 = → Predicted: 135.65, Actual: 137.0
# 75 + 28 = → Predicted: 102.36, Actual: 103.0
# 40 + 68 = → Predicted: 107.32, Actual: 108.0
# 98 * 56 = → Predicted: 168.56, Actual: 5488.0
# 49 + 26 = → Predicted: 74.49, Actual: 75.0
# 5 - 97 = → Predicted: -93.15, Actual: -92.0
# 69 - 79 = → Predicted: -10.49, Actual: -10.0
# 87 + 91 = → Predicted: 166.68, Actual: 178.0
# 78 + 56 = → Predicted: 132.07, Actual: 134.0
# 35 - 42 = → Predicted: -8.73, Actual: -7.0
# 96 + 49 = → Predicted: 144.59, Actual: 145.0
# 86 / 1 = → Predicted: 86.09, Actual: 86.0
# 84 * 81 = → Predicted: 168.56, Actual: 6804.0
# 88 / 4 = → Predicted: 19.57, Actual: 22.0
# 23 + 68 = → Predicted: 92.39, Actual: 91.0
# 94 / 94 = → Predicted: 1.19, Actual: 1.0
# 59 - 6 = → Predicted: 52.18, Actual: 53.0
# 46 + 71 = → Predicted: 116.74, Actual: 117.0
# 69 * 68 = → Predicted: 168.56, Actual: 4692.0
# 26 - 19 = → Predicted: 5.57, Actual: 7.0
# 51 / 17 = → Predicted: 4.12, Actual: 3.0
# 60 + 81 = → Predicted: 140.09, Actual: 141.0
# 20 + 2 = → Predicted: 21.32, Actual: 22.0
# 41 + 50 = → Predicted: 91.00, Actual: 91.0
# 31 - 29 = → Predicted: 2.27, Actual: 2.0
# 60 / 5 = → Predicted: 12.00, Actual: 12.0
# 49 / 7 = → Predicted: 8.95, Actual: 7.0
# 88 * 11 = → Predicted: 168.55, Actual: 968.0
# 63 / 7 = → Predicted: 10.91, Actual: 9.0
# 90 + 52 = → Predicted: 143.07, Actual: 142.0
# 21 / 7 = → Predicted: 3.65, Actual: 3.0
# 94 / 94 = → Predicted: 1.19, Actual: 1.0
# 91 + 22 = → Predicted: 110.25, Actual: 113.0
# 12 + 32 = → Predicted: 45.51, Actual: 44.0
# 11 - 99 = → Predicted: -87.35, Actual: -88.0
# 24 * 92 = → Predicted: 168.52, Actual: 2208.0
# 54 / 1 = → Predicted: 53.84, Actual: 54.0
# 28 / 1 = → Predicted: 27.61, Actual: 28.0
# 30 + 28 = → Predicted: 59.64, Actual: 58.0
# 98 / 49 = → Predicted: 1.17, Actual: 2.0
# 83 - 38 = → Predicted: 44.86, Actual: 45.0
# 62 - 45 = → Predicted: 16.07, Actual: 17.0
# 48 - 37 = → Predicted: 10.05, Actual: 11.0
# 99 + 24 = → Predicted: 122.63, Actual: 123.0
# 30 + 38 = → Predicted: 67.29, Actual: 68.0
# 53 - 83 = → Predicted: -29.42, Actual: -30.0
# 41 + 24 = → Predicted: 63.84, Actual: 65.0
# 83 + 59 = → Predicted: 140.04, Actual: 142.0
# 58 - 100 = → Predicted: -43.03, Actual: -42.0
# 9 * 49 = → Predicted: 168.50, Actual: 441.0
# 21 - 82 = → Predicted: -60.34, Actual: -61.0
# 45 / 5 = → Predicted: 9.49, Actual: 9.0
# 70 - 96 = → Predicted: -26.30, Actual: -26.0
# 60 - 94 = → Predicted: -34.45, Actual: -34.0
# 24 + 57 = → Predicted: 80.77, Actual: 81.0
# 5 - 73 = → Predicted: -69.09, Actual: -68.0
# 72 + 43 = → Predicted: 114.30, Actual: 115.0
# 98 - 33 = → Predicted: 61.88, Actual: 65.0
# 77 + 35 = → Predicted: 107.79, Actual: 112.0
# 4 - 91 = → Predicted: -89.76, Actual: -87.0
# 23 - 79 = → Predicted: -56.07, Actual: -56.0
# 87 / 87 = → Predicted: 1.19, Actual: 1.0
# 73 / 73 = → Predicted: 0.72, Actual: 1.0
# 34 + 71 = → Predicted: 104.89, Actual: 105.0
# 63 + 86 = → Predicted: 146.99, Actual: 149.0
# 89 - 90 = → Predicted: -1.22, Actual: -1.0
# 54 - 77 = → Predicted: -24.45, Actual: -23.0
# 95 * 83 = → Predicted: 168.56, Actual: 7885.0
# 4 * 75 = → Predicted: 168.49, Actual: 300.0
# 73 + 91 = → Predicted: 163.33, Actual: 164.0
# 100 + 89 = → Predicted: 167.38, Actual: 189.0
# 96 + 85 = → Predicted: 167.11, Actual: 181.0
# 4 + 37 = → Predicted: 40.72, Actual: 41.0
# 22 * 25 = → Predicted: 168.54, Actual: 550.0
# 18 / 2 = → Predicted: 9.25, Actual: 9.0
# 31 * 6 = → Predicted: 168.54, Actual: 186.0
# 45 / 1 = → Predicted: 43.89, Actual: 45.0
# 2 - 28 = → Predicted: -25.87, Actual: -26.0
# 87 * 26 = → Predicted: 168.56, Actual: 2262.0
# 82 * 73 = → Predicted: 168.56, Actual: 5986.0
# 32 / 2 = → Predicted: 15.94, Actual: 16.0
# 74 + 88 = → Predicted: 163.02, Actual: 162.0
# 6 - 78 = → Predicted: -73.49, Actual: -72.0
# 84 / 3 = → Predicted: 27.90, Actual: 28.0
# 36 + 5 = → Predicted: 40.75, Actual: 41.0
# 14 / 14 = → Predicted: 1.67, Actual: 1.0
# 23 * 1 = → Predicted: 163.52, Actual: 23.0
# 24 * 12 = → Predicted: 168.51, Actual: 288.0
# 48 + 85 = → Predicted: 132.12, Actual: 133.0
# 25 * 29 = → Predicted: 168.55, Actual: 725.0
# 83 + 55 = → Predicted: 137.33, Actual: 138.0
# 94 / 47 = → Predicted: 2.51, Actual: 2.0
# 14 * 49 = → Predicted: 168.53, Actual: 686.0
# 12 / 4 = → Predicted: 3.87, Actual: 3.0
# 6 * 67 = → Predicted: 168.51, Actual: 402.0
# 84 - 73 = → Predicted: 10.23, Actual: 11.0
# 68 - 65 = → Predicted: 2.03, Actual: 3.0
# 13 + 85 = → Predicted: 96.85, Actual: 98.0
# 3 - 12 = → Predicted: -9.10, Actual: -9.0
# 25 / 1 = → Predicted: 24.69, Actual: 25.0
# 90 * 46 = → Predicted: 168.56, Actual: 4140.0
# 20 - 64 = → Predicted: -44.19, Actual: -44.0
# 76 / 38 = → Predicted: 2.22, Actual: 2.0
# 94 + 51 = → Predicted: 145.67, Actual: 145.0
# 49 * 50 = → Predicted: 168.56, Actual: 2450.0
# 61 + 53 = → Predicted: 112.78, Actual: 114.0
# 19 * 50 = → Predicted: 168.54, Actual: 950.0
# 85 / 17 = → Predicted: 6.50, Actual: 5.0
# 91 + 29 = → Predicted: 120.81, Actual: 120.0
# 63 - 56 = → Predicted: 5.87, Actual: 7.0
# 61 / 61 = → Predicted: 0.26, Actual: 1.0
# 19 * 36 = → Predicted: 168.54, Actual: 684.0
# 68 + 32 = → Predicted: 97.80, Actual: 100.0
# 76 - 94 = → Predicted: -18.18, Actual: -18.0
# 98 + 19 = → Predicted: 116.77, Actual: 117.0
# 56 / 4 = → Predicted: 13.66, Actual: 14.0
# 2 - 59 = → Predicted: -58.32, Actual: -57.0
# 63 - 1 = → Predicted: 63.00, Actual: 62.0
# 16 / 1 = → Predicted: 15.79, Actual: 16.0
# 78 - 10 = → Predicted: 69.80, Actual: 68.0
# 77 + 74 = → Predicted: 151.38, Actual: 151.0
# 90 - 25 = → Predicted: 64.83, Actual: 65.0
# 51 / 51 = → Predicted: 0.91, Actual: 1.0
# 25 + 52 = → Predicted: 74.19, Actual: 77.0
# 7 / 7 = → Predicted: -0.04, Actual: 1.0
# 9 / 1 = → Predicted: 8.66, Actual: 9.0
# 50 * 58 = → Predicted: 168.55, Actual: 2900.0
# 60 + 58 = → Predicted: 117.05, Actual: 118.0
# 38 - 84 = → Predicted: -46.11, Actual: -46.0
# 82 * 23 = → Predicted: 168.56, Actual: 1886.0
# 81 + 4 = → Predicted: 85.08, Actual: 85.0
# 98 + 41 = → Predicted: 139.17, Actual: 139.0
# 6 + 85 = → Predicted: 88.01, Actual: 91.0
# 63 - 67 = → Predicted: -4.54, Actual: -4.0
# 14 + 71 = → Predicted: 85.60, Actual: 85.0
# 91 / 7 = → Predicted: 12.78, Actual: 13.0
# 97 - 42 = → Predicted: 54.53, Actual: 55.0
# 47 / 47 = → Predicted: 1.74, Actual: 1.0
# 93 / 93 = → Predicted: 1.34, Actual: 1.0
# 20 + 28 = → Predicted: 49.89, Actual: 48.0
# 82 + 36 = → Predicted: 118.14, Actual: 118.0
# 2 + 9 = → Predicted: 9.38, Actual: 11.0
# 32 / 2 = → Predicted: 15.94, Actual: 16.0
# 10 * 60 = → Predicted: 168.50, Actual: 600.0
# 2 * 6 = → Predicted: 168.23, Actual: 12.0
# 60 * 79 = → Predicted: 168.56, Actual: 4740.0
# 2 + 31 = → Predicted: 30.89, Actual: 33.0
# 79 - 47 = → Predicted: 30.45, Actual: 32.0
# 14 / 1 = → Predicted: 13.99, Actual: 14.0
# 33 + 17 = → Predicted: 51.28, Actual: 50.0
# 18 + 87 = → Predicted: 105.91, Actual: 105.0
# 29 * 22 = → Predicted: 168.55, Actual: 638.0
# 40 + 95 = → Predicted: 132.49, Actual: 135.0
# 87 * 33 = → Predicted: 168.56, Actual: 2871.0
# 21 + 5 = → Predicted: 23.66, Actual: 26.0
# 57 + 7 = → Predicted: 60.13, Actual: 64.0
# 46 * 2 = → Predicted: 163.64, Actual: 92.0
# 82 * 94 = → Predicted: 168.56, Actual: 7708.0
# 2 * 11 = → Predicted: 168.11, Actual: 22.0
# 90 * 91 = → Predicted: 168.56, Actual: 8190.0
# 75 / 25 = → Predicted: 2.57, Actual: 3.0
# 27 / 27 = → Predicted: -0.70, Actual: 1.0
# 1 - 100 = → Predicted: -88.05, Actual: -99.0
# 69 - 17 = → Predicted: 49.64, Actual: 52.0
# 12 + 84 = → Predicted: 94.52, Actual: 96.0
# 82 + 47 = → Predicted: 129.34, Actual: 129.0
# 45 - 98 = → Predicted: -53.32, Actual: -53.0
# 40 - 62 = → Predicted: -22.55, Actual: -22.0
# 91 + 15 = → Predicted: 106.02, Actual: 106.0
# 55 / 11 = → Predicted: 5.19, Actual: 5.0
# 65 + 25 = → Predicted: 90.61, Actual: 90.0
# 60 / 6 = → Predicted: 9.32, Actual: 10.0
# 28 + 15 = → Predicted: 42.56, Actual: 43.0
# 62 - 75 = → Predicted: -13.52, Actual: -13.0
# 8 - 93 = → Predicted: -86.12, Actual: -85.0
# 34 + 64 = → Predicted: 100.02, Actual: 98.0
# 81 * 70 = → Predicted: 168.56, Actual: 5670.0
# 19 - 39 = → Predicted: -23.05, Actual: -20.0
# 67 + 85 = → Predicted: 151.60, Actual: 152.0
# 11 - 16 = → Predicted: -4.16, Actual: -5.0
# 6 * 64 = → Predicted: 168.51, Actual: 384.0
# 10 * 33 = → Predicted: 168.49, Actual: 330.0
# 94 / 1 = → Predicted: 94.13, Actual: 94.0
# 37 - 99 = → Predicted: -63.32, Actual: -62.0
# 68 * 92 = → Predicted: 168.56, Actual: 6256.0
# 22 - 24 = → Predicted: -3.61, Actual: -2.0
# 41 + 2 = → Predicted: 34.86, Actual: 43.0
# 5 - 6 = → Predicted: 1.79, Actual: -1.0
# 24 * 47 = → Predicted: 168.52, Actual: 1128.0
# 66 - 51 = → Predicted: 13.77, Actual: 15.0
# 75 * 84 = → Predicted: 168.56, Actual: 6300.0
# 38 * 6 = → Predicted: 168.54, Actual: 228.0
# 83 + 42 = → Predicted: 123.86, Actual: 125.0
# 62 - 57 = → Predicted: 4.12, Actual: 5.0
# 89 + 8 = → Predicted: 94.80, Actual: 97.0
# 25 / 1 = → Predicted: 24.69, Actual: 25.0
# 26 * 82 = → Predicted: 168.54, Actual: 2132.0
# 51 + 77 = → Predicted: 127.07, Actual: 128.0
# 72 + 93 = → Predicted: 163.06, Actual: 165.0
# 49 * 3 = → Predicted: 168.54, Actual: 147.0
# 8 * 30 = → Predicted: 168.50, Actual: 240.0
# 25 / 1 = → Predicted: 24.69, Actual: 25.0
# 41 * 8 = → Predicted: 168.55, Actual: 328.0
# 68 / 1 = → Predicted: 66.25, Actual: 68.0
# 81 + 14 = → Predicted: 93.58, Actual: 95.0
# 92 * 35 = → Predicted: 168.56, Actual: 3220.0
# 17 * 77 = → Predicted: 168.53, Actual: 1309.0
# 2 / 1 = → Predicted: 2.35, Actual: 2.0
# 34 * 60 = → Predicted: 168.55, Actual: 2040.0
# 14 * 80 = → Predicted: 168.53, Actual: 1120.0
# 4 / 4 = → Predicted: 1.04, Actual: 1.0
# 5 / 5 = → Predicted: -0.69, Actual: 1.0
# 95 - 36 = → Predicted: 58.50, Actual: 59.0
# 14 + 87 = → Predicted: 100.11, Actual: 101.0
# 31 * 27 = → Predicted: 168.55, Actual: 837.0
# 78 + 24 = → Predicted: 101.41, Actual: 102.0
# 66 / 11 = → Predicted: 6.25, Actual: 6.0
# 2 + 57 = → Predicted: 57.36, Actual: 59.0
# 74 * 51 = → Predicted: 168.56, Actual: 3774.0
# 1 / 1 = → Predicted: 1.01, Actual: 1.0
# 70 - 52 = → Predicted: 17.41, Actual: 18.0
# 52 - 84 = → Predicted: -32.32, Actual: -32.0
# 94 * 29 = → Predicted: 168.56, Actual: 2726.0
# 90 * 46 = → Predicted: 168.56, Actual: 4140.0
# 47 + 35 = → Predicted: 82.38, Actual: 82.0
# 47 - 49 = → Predicted: -3.41, Actual: -2.0
# 97 / 97 = → Predicted: 1.41, Actual: 1.0
# 63 / 1 = → Predicted: 63.02, Actual: 63.0
# 70 + 68 = → Predicted: 137.38, Actual: 138.0
# 78 - 63 = → Predicted: 16.22, Actual: 15.0
# 35 / 35 = → Predicted: -1.10, Actual: 1.0
# 63 - 38 = → Predicted: 24.26, Actual: 25.0
# 86 + 60 = → Predicted: 145.61, Actual: 146.0
# 7 - 14 = → Predicted: -5.56, Actual: -7.0
# 25 - 3 = → Predicted: 21.49, Actual: 22.0
# 5 / 5 = → Predicted: -0.69, Actual: 1.0
# 32 * 47 = → Predicted: 168.55, Actual: 1504.0
# 93 + 71 = → Predicted: 164.89, Actual: 164.0
# 48 - 24 = → Predicted: 22.66, Actual: 24.0
# 20 / 10 = → Predicted: 0.55, Actual: 2.0
# 39 * 37 = → Predicted: 168.55, Actual: 1443.0
# 75 + 95 = → Predicted: 165.31, Actual: 170.0
# 94 + 28 = → Predicted: 119.49, Actual: 122.0
# 33 * 37 = → Predicted: 168.55, Actual: 1221.0
# 63 / 21 = → Predicted: 2.72, Actual: 3.0
# 62 + 18 = → Predicted: 81.57, Actual: 80.0
# 33 - 55 = → Predicted: -23.60, Actual: -22.0
# 24 * 71 = → Predicted: 168.52, Actual: 1704.0
# 38 + 86 = → Predicted: 123.51, Actual: 124.0
# 15 + 27 = → Predicted: 40.89, Actual: 42.0
# 37 * 38 = → Predicted: 168.55, Actual: 1406.0
# 37 / 1 = → Predicted: 35.87, Actual: 37.0
# 68 + 46 = → Predicted: 112.36, Actual: 114.0
# 79 * 29 = → Predicted: 168.56, Actual: 2291.0
# 30 * 43 = → Predicted: 168.55, Actual: 1290.0
# 90 + 45 = → Predicted: 135.00, Actual: 135.0
# 38 + 22 = → Predicted: 59.14, Actual: 60.0
# 14 + 29 = → Predicted: 41.92, Actual: 43.0
# 11 * 55 = → Predicted: 168.53, Actual: 605.0
# 67 / 1 = → Predicted: 66.56, Actual: 67.0
# 82 + 90 = → Predicted: 166.00, Actual: 172.0
# 71 - 3 = → Predicted: 68.21, Actual: 68.0
# 53 * 82 = → Predicted: 168.55, Actual: 4346.0
# 68 * 47 = → Predicted: 168.56, Actual: 3196.0
# 15 + 76 = → Predicted: 90.72, Actual: 91.0
# 98 + 76 = → Predicted: 166.74, Actual: 174.0
# 19 * 53 = → Predicted: 168.54, Actual: 1007.0
# 28 + 79 = → Predicted: 107.39, Actual: 107.0
# 85 / 17 = → Predicted: 6.50, Actual: 5.0
# 87 + 40 = → Predicted: 128.39, Actual: 127.0
# 69 + 26 = → Predicted: 92.96, Actual: 95.0
# 18 / 9 = → Predicted: 1.06, Actual: 2.0
# 34 * 29 = → Predicted: 168.55, Actual: 986.0
# 70 - 48 = → Predicted: 19.80, Actual: 22.0
# 6 - 77 = → Predicted: -70.51, Actual: -71.0
# 88 + 63 = → Predicted: 151.23, Actual: 151.0
# 53 * 95 = → Predicted: 168.55, Actual: 5035.0
# 55 + 14 = → Predicted: 69.19, Actual: 69.0
# 19 / 1 = → Predicted: 19.34, Actual: 19.0
# 96 + 30 = → Predicted: 125.97, Actual: 126.0
# 32 + 20 = → Predicted: 51.11, Actual: 52.0
# 18 - 2 = → Predicted: 17.18, Actual: 16.0
# 8 * 93 = → Predicted: 168.51, Actual: 744.0
# 33 + 92 = → Predicted: 124.71, Actual: 125.0
# 34 - 4 = → Predicted: 29.33, Actual: 30.0
# 48 / 6 = → Predicted: 8.00, Actual: 8.0
# 31 - 15 = → Predicted: 15.47, Actual: 16.0
# 60 * 55 = → Predicted: 168.56, Actual: 3300.0
# 84 * 77 = → Predicted: 168.56, Actual: 6468.0
# 88 / 2 = → Predicted: 43.91, Actual: 44.0
# 43 / 43 = → Predicted: 0.97, Actual: 1.0
# 1 + 23 = → Predicted: 24.19, Actual: 24.0
# 26 - 24 = → Predicted: 0.53, Actual: 2.0
# 68 / 68 = → Predicted: 0.71, Actual: 1.0
# 38 + 13 = → Predicted: 46.78, Actual: 51.0
# 28 - 71 = → Predicted: -43.26, Actual: -43.0
# 89 * 11 = → Predicted: 168.55, Actual: 979.0
# 5 / 5 = → Predicted: -0.69, Actual: 1.0
# 85 - 19 = → Predicted: 65.91, Actual: 66.0
# 80 - 24 = → Predicted: 53.82, Actual: 56.0
# 73 * 13 = → Predicted: 168.55, Actual: 949.0
# 50 / 2 = → Predicted: 24.68, Actual: 25.0
# 87 + 44 = → Predicted: 131.25, Actual: 131.0
# 83 + 82 = → Predicted: 163.62, Actual: 165.0
# 84 + 7 = → Predicted: 86.08, Actual: 91.0
# 43 - 54 = → Predicted: -11.35, Actual: -11.0
# 78 / 26 = → Predicted: 4.42, Actual: 3.0
# 48 / 6 = → Predicted: 8.00, Actual: 8.0
# 64 - 83 = → Predicted: -18.89, Actual: -19.0
# 91 - 62 = → Predicted: 27.72, Actual: 29.0
# 27 * 29 = → Predicted: 168.54, Actual: 783.0
# 55 * 55 = → Predicted: 168.55, Actual: 3025.0
# 27 + 42 = → Predicted: 68.87, Actual: 69.0
# 55 * 67 = → Predicted: 168.55, Actual: 3685.0
# 7 * 83 = → Predicted: 168.50, Actual: 581.0
# 77 / 77 = → Predicted: 0.83, Actual: 1.0
# 10 * 53 = → Predicted: 168.50, Actual: 530.0
# 78 / 26 = → Predicted: 4.42, Actual: 3.0
# 4 - 2 = → Predicted: 3.91, Actual: 2.0
# 43 / 1 = → Predicted: 42.07, Actual: 43.0
# 43 / 43 = → Predicted: 0.97, Actual: 1.0
# 57 / 1 = → Predicted: 56.66, Actual: 57.0
# 26 - 32 = → Predicted: -7.44, Actual: -6.0
# 38 / 38 = → Predicted: 0.89, Actual: 1.0
# 51 * 26 = → Predicted: 168.55, Actual: 1326.0
# 43 * 15 = → Predicted: 168.55, Actual: 645.0
# 22 + 7 = → Predicted: 23.72, Actual: 29.0
# 78 + 68 = → Predicted: 144.72, Actual: 146.0
# 33 * 63 = → Predicted: 168.55, Actual: 2079.0

# %%
def forward_embedded(embedded_input):
    """
    embedded_input: tensor of shape [batch, seq_len, embed_dim]
    """
    lstm_out, (h_n, c_n) = model.lstm(embedded_input)
    final_hidden = h_n[-1]
    out = model.fc(final_hidden)
    return out.squeeze(1)

# %%
num_samples = 100
n_cols= 5
n_rows= math.ceil(num_samples / n_cols)
ig = IntegratedGradients(forward_embedded)

fig = make_subplots(rows=n_rows, cols=n_cols,
                    horizontal_spacing=0.01, vertical_spacing=0.02)

for i in range(num_samples):
    ids   = X_test[i].unsqueeze(0)
    toks  = [list(token2idx.keys())[list(token2idx.values()).index(t.item())] for t in ids[0]]
    eqn   = " ".join(toks)

    emb   = model.embedding(ids).detach().requires_grad_()
    attrs,_ = ig.attribute(emb, return_convergence_delta=True)
    scores = attrs.squeeze(0).sum(dim=1)
    scores = scores / torch.norm(scores)
    img    = scores.detach().numpy()[None, :]

    r, c = divmod(i, n_cols)
    fig.add_trace(
        go.Heatmap(
            z=img,
            colorscale='RdBu',
            zmin=-1, zmax=1,
            showscale=False,
            hovertemplate=f"<b>{eqn}</b><br>Token: %{{x}}<br>Attrib: %{{z:.3f}}<extra></extra>",
            x=toks, y=['']
        ),
        row=r+1, col=c+1
    )

fig.update_layout(
    height=25*n_rows+100, width=1000,
    margin=dict(l=10, r=10, t=30, b=10),
    template='plotly_white'
)
fig.write_html("attribution_grid.html")
